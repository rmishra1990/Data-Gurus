# %%
import pandas as pd
from census import Census
import censusdata
import requests
import json


sdf = pd.read_csv("../Resources/source_data.csv")
sdf = sdf[["Name","Latitude","Longitude","Street1","Street2","Street3","City","CountrySubdivisionCode"]]
sdf
# Out:
#                                     Name  Latitude  Longitude  \
# 0                               Galloway     39.46     -74.49
# 1                 Acme - Allendale #1095     41.03     -74.13
# 2                    Target Ocean T-1378     40.23     -74.05
# 3                Atlantic City, The Walk     39.36     -74.44
# 4            Golden Nugget-Atlantic City     39.38     -74.43
# 5                  Tropicana Marketplace     39.35     -74.45
# 6     Trump Taj Mahal-Atlantic City-Main     39.36     -74.42
# 7                  Acme - Barnegat #7921     39.76     -74.25
# 8                     Bernards-Riverwalk     40.65     -74.58
# 9             Stop & Shop - Bayonne #853     40.67     -74.11
# 10                 Village at Bedminster     40.65     -74.64
# 11              NJ Monmouth Travel Plaza     40.02     -74.27
# 12        Paramus Park Mall Center Court     40.96     -74.07
# 13                  Bernardsville Center     40.72     -74.56
# 14            Gloucester Premium Outlets     39.78     -75.05
# 15                  Acme - Boonton #1582     40.91     -74.40
# 16                            Bordentown     40.13     -74.72
# 17                            Branchburg     40.61     -74.69
# 18                    Whitehouse Station     40.62     -74.76
# 19                   Target Brick T-1153     40.06     -74.15
# 20         Bridgewater Mall-Level 1 Side     40.59     -74.62
# 21             Target Bridgewater T-1224     40.56     -74.56
# 22    The Village at Bridgewater Commons     40.58     -74.61
# 23              Target Burlington T-1158     40.04     -74.82
# 24        Rutgers U/Camden-Student Union     39.95     -75.12
# 25                  Cedar Knolls Hanover     40.81     -74.47
# 26                               Chatham     40.75     -74.43
# 27                      480 Evesham Road     39.86     -74.97
# 28              600 Route 38 Cherry Hill     39.94     -75.05
# 29                  Chapel & Haddonfield     39.93     -75.03
# ..                                   ...       ...        ...
# 217                    Ocean County Mall     39.98     -74.18
# 218          Stop & Shop-Toms River #811     39.95     -74.16
# 219                   Toms River Route 9     40.05     -74.22
# 220        Richard Stockton Travel Plaza     40.18     -74.64
# 221           5340 Route 42 Turnersville     39.76     -75.05
# 222           Target Turnersville T-1132     39.73     -75.04
# 223     Kean University-Thompson Library     40.68     -74.24
# 224               Rt. 22 - Center Island     40.69     -74.31
# 225                  Target Union T-2141     40.72     -74.29
# 226                  Acme - Vernon #2820     41.19     -74.49
# 227             Vineland Cumberland Mall     39.43     -75.04
# 228  Cedar Hill Shopping Center,Voorhees     39.84     -74.93
# 229                               Warren     40.62     -74.49
# 230                      Target Watchung     40.64     -74.41
# 231        Berdan Ave & Hamburg Turnpike     40.96     -74.24
# 232                 Macy's - Willowbrook     40.89     -74.26
# 233        Paterson-Hamburg Tpke - Wayne     40.94     -74.20
# 234                         Wayne Rt. 23     40.95     -74.27
# 235                Wayne West Belt Plaza     40.89     -74.25
# 236          Willowbrook Mall Food Court     40.89     -74.26
# 237                        West Caldwell     40.85     -74.30
# 238                        West New York     40.78     -74.01
# 239                            Westfield     40.65     -74.35
# 240                      Westwood Avenue     40.99     -74.03
# 241     NJ Grover Cleveland Travel Plaza     40.56     -74.26
# 242            Thomas Edison Travel Plza     40.56     -74.27
# 243                      Woodbridge Mall     40.56     -74.30
# 244          Acme - Woodcliff Lake #1069     41.04     -74.07
# 245                              Wyckoff     41.01     -74.17
# 246     Woodrow Wilson Travel Plaza - N6     40.18     -74.63
#
#                                    Street1       Street2  \
# 0                       405 S. Pitney Road           NaN
# 1                         45 Demercurio Dr           NaN
# 2                      2331 State Route 66           NaN
# 3                120 North Michigan Avenue           NaN
# 4                            1 Castle Blvd           NaN
# 5                           2831 Boardwalk           NaN
# 6           1000 Boardwalk at Virginia Ave           NaN
# 7                            912 W Bay Ave           NaN
# 8                    655 Martinsville Road           NaN
# 9                            1 Lefante Way           NaN
# 10                  432 US Highway 202/206           NaN
# 11      Garden State Pkwy, Mile Marker 100           NaN
# 12                        700 Paramus Park           NaN
# 13                       80 Morristown Rd.       Unit 10
# 14                 1125 S Black Horse Pike     Space 575
# 15                       550 Myrtle Avenue           NaN
# 16                     282 Dunns Mill Road           NaN
# 17        240 Raritan Valley College Drive           NaN
# 18                    531 Route 22 East #8           NaN
# 19                        570 Rte. 70 West           NaN
# 20                         400 Commons Way          2475
# 21                      200 Promenade Blvd           NaN
# 22                    610 Commons Way 4300           NaN
# 23                          2703 Route 541           NaN
# 24                             326 Penn St           NaN
# 25                      178 Hanover Avenue           101
# 26                        640 Shunpike Rd.           NaN
# 27                        480 Evesham Road           NaN
# 28                               600 Rt 38           NaN
# 29                    512 Haddonfield Road           NaN
# ..                                     ...           ...
# 217                        1201 HOOPER AVE          1072
# 218                      353 Route 37 East           NaN
# 219                       2360 Lakewood Rd           NaN
# 220                     200 Uncle Petes Rd           NaN
# 221                          5340 Route 42           NaN
# 222                  4001 Black Horse Pike           NaN
# 223                        1000 Morris Ave           NaN
# 224                     2698 Route 22 East           NaN
# 225                   2235 Springfield Ave           NaN
# 226                             530 CR-515           NaN
# 227                    3849 S. Delsea Road  Space #A0013
# 228                           148 Route 73           NaN
# 229                      4 Mount Bethel Rd           NaN
# 230                     1515 US Highway 22           NaN
# 231                  1118 Hamburg Turnpike           NaN
# 232                  1100 Willowbrook Blvd           NaN
# 233                   183 Hamburg Turnpike           NaN
# 234                    1606 Route 23 North           NaN
# 235                      57 state route 23           NaN
# 236                  1400 Willowbrook Mall           NaN
# 237                       546 Passaic Ave.           NaN
# 238                   55-1 Riverwalk Place           NaN
# 239                     117 Central Avenue           NaN
# 240                    102 Westwood Avenue           104
# 241                       Mile Marker 92.9           NaN
# 242  New Jersey Turnpike, Mile Post 92.9 S           NaN
# 243            250 Woodbridge Center Drive           NaN
# 244                  520 Chestnut Ridge Rd           NaN
# 245                    325 Franklin Avenue           NaN
# 246      Mile post 57.8-North, NJ Turnpike           NaN
#
#                                      Street3            City  \
# 0    Galloway Village Square Shopping Center         Absecon
# 1                                        NaN       Allendale
# 2                                        NaN     Asbury Park
# 3                                        NaN   Atlantic City
# 4                                        NaN   Atlantic City
# 5                                        NaN   Atlantic City
# 6                                        NaN   Atlantic City
# 7                                        NaN        Barnegat
# 8                                        NaN        Bernards
# 9                                        NaN         Bayonne
# 10                     Village at Bedminster      Bedminster
# 11                                       NaN          Belmar
# 12                                       NaN         Paramus
# 13                                       NaN   Bernardsville
# 14                                       NaN      Gloucester
# 15                                       NaN         Boonton
# 16                ACME Commons at Bordentown      Bordentown
# 17                     Shoppes at Branchburg      Branchburg
# 18                                       NaN      Branchburg
# 19                                       NaN           Brick
# 20                       Bridgewater Commons     Bridgewater
# 21                                       NaN     Bridgewater
# 22        The Village at Bridgewater Commons     Bridgewater
# 23                                       NaN      Burlington
# 24                                       NaN          Camden
# 25                                       NaN         Hanover
# 26                                       NaN         Chatham
# 27                  Short Hills Towne Centre     Cherry Hill
# 28                                       NaN     Cherry Hill
# 29                                       NaN     Cherry Hill
# ..                                       ...             ...
# 217                        Ocean County Mall      Toms River
# 218                                      NaN      Toms River
# 219                                      NaN      Toms River
# 220                                      NaN         Trenton
# 221                                      NaN      Washington
# 222                                      NaN      Washington
# 223                                      NaN           Union
# 224                                      NaN           Union
# 225                                      NaN           Union
# 226                                      NaN          Vernon
# 227                          Cumberland Mall        Vineland
# 228               Cedar Hill Shopping Center        Voorhees
# 229                                      NaN          Warren
# 230                                      NaN        Watchung
# 231                                      NaN           Wayne
# 232                         Willowbrook Mall           Wayne
# 233                                      NaN           Wayne
# 234                                      NaN           Wayne
# 235                                      NaN           Wayne
# 236                         Willowbrook Mall           Wayne
# 237                                      NaN   West Caldwell
# 238                                      NaN   West New York
# 239                                      NaN       Westfield
# 240                          Meisel Building        Westwood
# 241                                      NaN      Woodbridge
# 242                                      NaN      Woodbridge
# 243                        Woodbridge Center      Woodbridge
# 244                                      NaN  Woodcliff Lake
# 245                                      NaN         Wyckoff
# 246                                      NaN        Hamilton
#
#     CountrySubdivisionCode
# 0                       NJ
# 1                       NJ
# 2                       NJ
# 3                       NJ
# 4                       NJ
# 5                       NJ
# 6                       NJ
# 7                       NJ
# 8                       NJ
# 9                       NJ
# 10                      NJ
# 11                      NJ
# 12                      NJ
# 13                      NJ
# 14                      NJ
# 15                      NJ
# 16                      NJ
# 17                      NJ
# 18                      NJ
# 19                      NJ
# 20                      NJ
# 21                      NJ
# 22                      NJ
# 23                      NJ
# 24                      NJ
# 25                      NJ
# 26                      NJ
# 27                      NJ
# 28                      NJ
# 29                      NJ
# ..                     ...
# 217                     NJ
# 218                     NJ
# 219                     NJ
# 220                     NJ
# 221                     NJ
# 222                     NJ
# 223                     NJ
# 224                     NJ
# 225                     NJ
# 226                     NJ
# 227                     NJ
# 228                     NJ
# 229                     NJ
# 230                     NJ
# 231                     NJ
# 232                     NJ
# 233                     NJ
# 234                     NJ
# 235                     NJ
# 236                     NJ
# 237                     NJ
# 238                     NJ
# 239                     NJ
# 240                     NJ
# 241                     NJ
# 242                     NJ
# 243                     NJ
# 244                     NJ
# 245                     NJ
# 246                     NJ
#
# [247 rows x 8 columns]

# %%
# api_key = "20d727d32e443da6897d6a50cdd95b1135f81bd0"
# c = Census(api_key, year=2017)
# census_data = c.acs5.get(("NAME", "B19013_001E", "B01003_001E", "B01002_001E",
#                           "B19301_001E",
#                           "B17001_002E",
#                           "B23025_005E"), {'for': 'state:34'})

# # Convert to DataFrame
# census_pd = pd.DataFrame(census_data)

# # Column Reordering
# census_pd = census_pd.rename(columns={"B01003_001E": "Population",
#                                       "B01002_001E": "Median Age",
#                                       "B19013_001E": "Household Income",
#                                       "B19301_001E": "Per Capita Income",
#                                       "B17001_002E": "Poverty Count",
#                                       "B23025_005E": "Unemployment Count",
#                                       "NAME": "Name", "state": "State"})

# %%
# ACS 1-Year Detailed Tables 2017 
# https://api.census.gov/data.html
# https://api.census.gov/data/2017/acs/acs1
# https://api.census.gov/data/2017/acs/acs1/geography.html
# https://api.census.gov/data/2017/acs/acs1/variables.html
# # https://api.census.gov/data/2017/acs/acs1/examples.html
    
    
# # 060 county subdivision

# censusdata.geographies(censusdata.censusgeo([('state', '34')]), 'acs5', 2015)
# censusdata.geographies(censusdata.censusgeo([('state', '34'), ('county', '*')]), 'acs5', 2015)

# mydata = censusdata.download('acs5', 2017,
#                              censusdata.censusgeo([('state', '34'), ('county', '*'), ('county subdivision', '*')]),
#                              ['B23025_003E', 'B23025_005E'])

# %%
# census_pd

# %%
import pandas as pd
import censusdata
mydata = censusdata.download('acs5', 2017,
                            censusdata.censusgeo([('state','34'), ('county', '*'),
                            ('county subdivision','*')]),
                            ['B19013_001E', 'B01003_001E', 'B01001_002E',
                             'B01001A_001E', 'B01001B_001E', 'B01001D_001E', 'B01001I_001E',
                             'B23025_004E', 'B01002A_001E', 'B09001_001E',
                             'B08136_001E'])


mydata['city'] = mydata.index
mydata = mydata.reset_index()

cities = []
clean = []
length = len(mydata['city'])
for i in range (0,length):
    cities.append(str(mydata['city'].tolist()[i]).split(',')[0])
for i in cities:
    end = (len(i.split(' ')))
    i = (i.split(' ')[:end-1])
    clean.append(" ".join(i))
    
df = pd.DataFrame({"City": [],"Income":[],"Population":[], "Male Pop (%)":[],
                   "White (%)":[],"Black (%)":[],"Asian (%)":[],"Hispanic (%)":[],
                   "Employed (%)":[], "Travel Time to Work (mins)":[],
                  "Median Age":[], "Age <18 (%)":[]})
df['City'] = clean
df['Income'] = mydata["B19013_001E"]
df['Population'] = mydata['B01003_001E']
df['Male Pop (%)'] = ((mydata['B01001_002E'])/(mydata['B01003_001E'])*100).round(2)
df["White (%)"] = ((mydata['B01001A_001E'])/(mydata['B01003_001E'])*100).round(2)
df["Black (%)"] = ((mydata['B01001B_001E'])/(mydata['B01003_001E'])*100).round(2)
df["Asian (%)"] = ((mydata['B01001D_001E'])/(mydata['B01003_001E'])*100).round(2)
df["Hispanic (%)"] = ((mydata['B01001I_001E'])/(mydata['B01003_001E'])*100).round(2)
df["Employed (%)"] = ((mydata['B23025_004E'])/(mydata['B01003_001E'])*100).round(2)
df['Median Age'] = mydata['B01002A_001E']
df['Age <18 (%)'] = ((mydata['B09001_001E'])/(mydata['B01003_001E'])*100).round(2)
df["Travel Time to Work (mins)"] = ((mydata['B08136_001E'])/(mydata['B23025_004E'])).round(0)



df.head()
# Out:
#            City  Income  Population  Male Pop (%)  White (%)  Black (%)  \
# 0  West Windsor  175684       28289         48.03      47.79       2.69
# 1  East Windsor   85636       27675         47.43      65.92       8.14
# 2      Hopewell  113125        1976         46.96      93.12       1.16
# 3    Hightstown   72973        5527         48.45      75.72       6.66
# 4      Hopewell  129320       18503         50.40      83.99       5.53
#
#    Asian (%)  Hispanic (%)  Employed (%)  Travel Time to Work (mins)  \
# 0      46.65          3.02         50.71                        40.0
# 1      19.72         23.17         49.61                        31.0
# 2       3.95          3.19         55.36                         NaN
# 3       4.67         36.11         53.48                         NaN
# 4       6.63          5.38         50.01                         NaN
#
#    Median Age  Age <18 (%)
# 0        45.3        26.15
# 1        39.0        24.07
# 2        43.6        24.75
# 3        39.0        19.63
# 4        47.3        21.87

# %%
census_cities_df = mydata['city'].unique
census_cities_df
# Out:
# <bound method Series.unique of 0      West Windsor township, Mercer County, New Jers...
# 1      East Windsor township, Mercer County, New Jers...
# 2      Hopewell borough, Mercer County, New Jersey: S...
# 3      Hightstown borough, Mercer County, New Jersey:...
# 4      Hopewell township, Mercer County, New Jersey: ...
# 5      Ewing township, Mercer County, New Jersey: Sum...
# 6      Hamilton township, Mercer County, New Jersey: ...
# 7      Pennington borough, Mercer County, New Jersey:...
# 8      Lawrence township, Mercer County, New Jersey: ...
# 9      Trenton city, Mercer County, New Jersey: Summa...
# 10     Frankford township, Sussex County, New Jersey:...
# 11     Hampton township, Sussex County, New Jersey: S...
# 12     Sussex borough, Sussex County, New Jersey: Sum...
# 13     Andover borough, Sussex County, New Jersey: Su...
# 14     Stillwater township, Sussex County, New Jersey...
# 15     Hardyston township, Sussex County, New Jersey:...
# 16     Newton town, Sussex County, New Jersey: Summar...
# 17     Montague township, Sussex County, New Jersey: ...
# 18     Walpack township, Sussex County, New Jersey: S...
# 19     Fredon township, Sussex County, New Jersey: Su...
# 20     Hopatcong borough, Sussex County, New Jersey: ...
# 21     Sandyston township, Sussex County, New Jersey:...
# 22     Sparta township, Sussex County, New Jersey: Su...
# 23     Andover township, Sussex County, New Jersey: S...
# 24     Franklin borough, Sussex County, New Jersey: S...
# 25     Hamburg borough, Sussex County, New Jersey: Su...
# 26     Lafayette township, Sussex County, New Jersey:...
# 27     Wantage township, Sussex County, New Jersey: S...
# 28     Byram township, Sussex County, New Jersey: Sum...
# 29     Stanhope borough, Sussex County, New Jersey: S...
#                              ...
# 540    Interlaken borough, Monmouth County, New Jerse...
# 541    Long Branch city, Monmouth County, New Jersey:...
# 542    Shrewsbury township, Monmouth County, New Jers...
# 543    Eatontown borough, Monmouth County, New Jersey...
# 544    Millville city, Cumberland County, New Jersey:...
# 545    Vineland city, Cumberland County, New Jersey: ...
# 546    Lawrence township, Cumberland County, New Jers...
# 547    Bridgeton city, Cumberland County, New Jersey:...
# 548    Greenwich township, Cumberland County, New Jer...
# 549    Shiloh borough, Cumberland County, New Jersey:...
# 550    Commercial township, Cumberland County, New Je...
# 551    County subdivisions not defined, Cumberland Co...
# 552    Deerfield township, Cumberland County, New Jer...
# 553    Hopewell township, Cumberland County, New Jers...
# 554    Rocky Hill borough, Somerset County, New Jerse...
# 555    South Bound Brook borough, Somerset County, Ne...
# 556    Green Brook township, Somerset County, New Jer...
# 557    Hillsborough township, Somerset County, New Je...
# 558    Millstone borough, Somerset County, New Jersey...
# 559    Montgomery township, Somerset County, New Jers...
# 560    Raritan borough, Somerset County, New Jersey: ...
# 561    Watchung borough, Somerset County, New Jersey:...
# 562    Bedminster township, Somerset County, New Jers...
# 563    Bernards township, Somerset County, New Jersey...
# 564    Franklin township, Somerset County, New Jersey...
# 565    Somerville borough, Somerset County, New Jerse...
# 566    Bound Brook borough, Somerset County, New Jers...
# 567    Branchburg township, Somerset County, New Jers...
# 568    Far Hills borough, Somerset County, New Jersey...
# 569    Bridgewater township, Somerset County, New Jer...
# Name: city, Length: 570, dtype: object>

# %%
df.to_csv("../Resources/census_data.csv")

# %%
merged = pd.merge(sdf, df, how='left', on='City')

# %%
merged.isna().sum()
# Out:
# Name                            0
# Latitude                        0
# Longitude                       0
# Street1                         0
# Street2                       262
# Street3                       222
# City                            0
# CountrySubdivisionCode          0
# Income                          2
# Population                      2
# Male Pop (%)                    2
# White (%)                       2
# Black (%)                       2
# Asian (%)                       2
# Hispanic (%)                    2
# Employed (%)                    2
# Travel Time to Work (mins)    137
# Median Age                      2
# Age <18 (%)                     2
# dtype: int64

# %%
merged[merged.Income.isna()== True]
# Out:
#                       Name  Latitude  Longitude              Street1 Street2  \
# 207              Princeton     40.35     -74.66    100 Nassau Street     NaN
# 208  Princeton Market Fair     40.31     -74.66  3535 Rt. 1 Ste. 426     NaN
#
#                    Street3       City CountrySubdivisionCode  Income  \
# 207                    NaN  Princeton                     NJ     NaN
# 208  Princeton Market Fair  Princeton                     NJ     NaN
#
#      Population  Male Pop (%)  White (%)  Black (%)  Asian (%)  Hispanic (%)  \
# 207         NaN           NaN        NaN        NaN        NaN           NaN
# 208         NaN           NaN        NaN        NaN        NaN           NaN
#
#      Employed (%)  Travel Time to Work (mins)  Median Age  Age <18 (%)
# 207           NaN                         NaN         NaN          NaN
# 208           NaN                         NaN         NaN          NaN

# %%
merged
# Out:
#                                     Name  Latitude  Longitude  \
# 0                               Galloway     39.46     -74.49
# 1                 Acme - Allendale #1095     41.03     -74.13
# 2                    Target Ocean T-1378     40.23     -74.05
# 3                    Target Ocean T-1378     40.23     -74.05
# 4                  Tropicana Marketplace     39.35     -74.45
# 5                Atlantic City, The Walk     39.36     -74.44
# 6    Tropicana Casino & Resort-The Quart     39.35     -74.44
# 7     Trump Taj Mahal-Atlantic City-Main     39.36     -74.42
# 8            Golden Nugget-Atlantic City     39.38     -74.43
# 9                  Acme - Barnegat #7921     39.76     -74.25
# 10                    Bernards-Riverwalk     40.65     -74.58
# 11            Stop & Shop - Bayonne #853     40.67     -74.11
# 12                 Village at Bedminster     40.65     -74.64
# 13              NJ Monmouth Travel Plaza     40.02     -74.27
# 14        Paramus Park Mall Center Court     40.96     -74.07
# 15                  Bernardsville Center     40.72     -74.56
# 16            Gloucester Premium Outlets     39.78     -75.05
# 17                  Acme - Boonton #1582     40.91     -74.40
# 18                  Acme - Boonton #1582     40.91     -74.40
# 19                  Acme - Boonton #1582     40.91     -74.40
# 20                  Acme - Boonton #1582     40.91     -74.40
# 21                            Bordentown     40.13     -74.72
# 22                            Bordentown     40.13     -74.72
# 23                            Bordentown     40.13     -74.72
# 24                            Bordentown     40.13     -74.72
# 25                    Whitehouse Station     40.62     -74.76
# 26                            Branchburg     40.61     -74.69
# 27                   Target Brick T-1153     40.06     -74.15
# 28         Teavana - Bridgewater Commons     40.59     -74.62
# 29    The Village at Bridgewater Commons     40.58     -74.61
# ..                                   ...       ...        ...
# 313               Rt. 22 - Center Island     40.69     -74.31
# 314     Kean University-Thompson Library     40.68     -74.24
# 315     Kean University-Thompson Library     40.68     -74.24
# 316     Kean University-Thompson Library     40.68     -74.24
# 317     Kean University-Thompson Library     40.68     -74.24
# 318                  Target Union T-2141     40.72     -74.29
# 319                  Target Union T-2141     40.72     -74.29
# 320                  Target Union T-2141     40.72     -74.29
# 321                  Target Union T-2141     40.72     -74.29
# 322                  Acme - Vernon #2820     41.19     -74.49
# 323             Vineland Cumberland Mall     39.43     -75.04
# 324  Cedar Hill Shopping Center,Voorhees     39.84     -74.93
# 325                               Warren     40.62     -74.49
# 326                      Target Watchung     40.64     -74.41
# 327        Paterson-Hamburg Tpke - Wayne     40.94     -74.20
# 328                         Wayne Rt. 23     40.95     -74.27
# 329          Willowbrook Mall Food Court     40.89     -74.26
# 330                Wayne West Belt Plaza     40.89     -74.25
# 331        Berdan Ave & Hamburg Turnpike     40.96     -74.24
# 332                 Macy's - Willowbrook     40.89     -74.26
# 333                        West Caldwell     40.85     -74.30
# 334                        West New York     40.78     -74.01
# 335                            Westfield     40.65     -74.35
# 336                      Westwood Avenue     40.99     -74.03
# 337                      Woodbridge Mall     40.56     -74.30
# 338     NJ Grover Cleveland Travel Plaza     40.56     -74.26
# 339            Thomas Edison Travel Plza     40.56     -74.27
# 340          Acme - Woodcliff Lake #1069     41.04     -74.07
# 341                              Wyckoff     41.01     -74.17
# 342     Woodrow Wilson Travel Plaza - N6     40.18     -74.63
#
#                                    Street1       Street2  \
# 0                       405 S. Pitney Road           NaN
# 1                         45 Demercurio Dr           NaN
# 2                      2331 State Route 66           NaN
# 3                      2331 State Route 66           NaN
# 4                           2831 Boardwalk           NaN
# 5                120 North Michigan Avenue           NaN
# 6                           2831 Boardwalk           NaN
# 7           1000 Boardwalk at Virginia Ave           NaN
# 8                            1 Castle Blvd           NaN
# 9                            912 W Bay Ave           NaN
# 10                   655 Martinsville Road           NaN
# 11                           1 Lefante Way           NaN
# 12                  432 US Highway 202/206           NaN
# 13      Garden State Pkwy, Mile Marker 100           NaN
# 14                        700 Paramus Park           NaN
# 15                       80 Morristown Rd.       Unit 10
# 16                 1125 S Black Horse Pike     Space 575
# 17                       550 Myrtle Avenue           NaN
# 18                       550 Myrtle Avenue           NaN
# 19                       550 Myrtle Avenue           NaN
# 20                       550 Myrtle Avenue           NaN
# 21                     282 Dunns Mill Road           NaN
# 22                     282 Dunns Mill Road           NaN
# 23                     282 Dunns Mill Road           NaN
# 24                     282 Dunns Mill Road           NaN
# 25                    531 Route 22 East #8           NaN
# 26        240 Raritan Valley College Drive           NaN
# 27                        570 Rte. 70 West           NaN
# 28                         400 COMMONS WAY   Space# 2440
# 29                    610 Commons Way 4300           NaN
# ..                                     ...           ...
# 313                     2698 Route 22 East           NaN
# 314                        1000 Morris Ave           NaN
# 315                        1000 Morris Ave           NaN
# 316                        1000 Morris Ave           NaN
# 317                        1000 Morris Ave           NaN
# 318                   2235 Springfield Ave           NaN
# 319                   2235 Springfield Ave           NaN
# 320                   2235 Springfield Ave           NaN
# 321                   2235 Springfield Ave           NaN
# 322                             530 CR-515           NaN
# 323                    3849 S. Delsea Road  Space #A0013
# 324                           148 Route 73           NaN
# 325                      4 Mount Bethel Rd           NaN
# 326                     1515 US Highway 22           NaN
# 327                   183 Hamburg Turnpike           NaN
# 328                    1606 Route 23 North           NaN
# 329                  1400 Willowbrook Mall           NaN
# 330                      57 state route 23           NaN
# 331                  1118 Hamburg Turnpike           NaN
# 332                  1100 Willowbrook Blvd           NaN
# 333                       546 Passaic Ave.           NaN
# 334                   55-1 Riverwalk Place           NaN
# 335                     117 Central Avenue           NaN
# 336                    102 Westwood Avenue           104
# 337            250 Woodbridge Center Drive           NaN
# 338                       Mile Marker 92.9           NaN
# 339  New Jersey Turnpike, Mile Post 92.9 S           NaN
# 340                  520 Chestnut Ridge Rd           NaN
# 341                    325 Franklin Avenue           NaN
# 342      Mile post 57.8-North, NJ Turnpike           NaN
#
#                                      Street3            City  \
# 0    Galloway Village Square Shopping Center         Absecon
# 1                                        NaN       Allendale
# 2                                        NaN     Asbury Park
# 3                                        NaN     Asbury Park
# 4                                        NaN   Atlantic City
# 5                                        NaN   Atlantic City
# 6                                        NaN   Atlantic City
# 7                                        NaN   Atlantic City
# 8                                        NaN   Atlantic City
# 9                                        NaN        Barnegat
# 10                                       NaN   Basking Ridge
# 11                                       NaN         Bayonne
# 12                     Village at Bedminster      Bedminster
# 13                                       NaN         Bellmar
# 14                                       NaN          Bergen
# 15                                       NaN   Bernardsville
# 16                                       NaN       Blackwood
# 17                                       NaN         Boonton
# 18                                       NaN         Boonton
# 19                                       NaN         Boonton
# 20                                       NaN         Boonton
# 21                ACME Commons at Bordentown      Bordentown
# 22                ACME Commons at Bordentown      Bordentown
# 23                ACME Commons at Bordentown      Bordentown
# 24                ACME Commons at Bordentown      Bordentown
# 25                                       NaN      Branchburg
# 26                     Shoppes at Branchburg      Branchburg
# 27                                       NaN           Brick
# 28                       Bridgewater Commons     Bridgewater
# 29        The Village at Bridgewater Commons     Bridgewater
# ..                                       ...             ...
# 313                                      NaN           Union
# 314                                      NaN           Union
# 315                                      NaN           Union
# 316                                      NaN           Union
# 317                                      NaN           Union
# 318                                      NaN           Union
# 319                                      NaN           Union
# 320                                      NaN           Union
# 321                                      NaN           Union
# 322                                      NaN          Vernon
# 323                          Cumberland Mall        Vineland
# 324               Cedar Hill Shopping Center        Voorhees
# 325                                      NaN          Warren
# 326                                      NaN        Watchung
# 327                                      NaN           Wayne
# 328                                      NaN           Wayne
# 329                         Willowbrook Mall           Wayne
# 330                                      NaN           Wayne
# 331                                      NaN           Wayne
# 332                         Willowbrook Mall           Wayne
# 333                                      NaN   West Caldwell
# 334                                      NaN   West New York
# 335                                      NaN       Westfield
# 336                          Meisel Building        Westwood
# 337                        Woodbridge Center      Woodbridge
# 338                                      NaN      Woodbridge
# 339                                      NaN      Woodbridge
# 340                                      NaN  Woodcliff Lake
# 341                                      NaN         Wyckoff
# 342                                      NaN       Yardville
#
#     CountrySubdivisionCode    Income  Population
# 0                       NJ   63887.0      8370.0
# 1                       NJ  151875.0      6820.0
# 2                       NJ   39324.0     15830.0
# 3                       NJ   39324.0     15830.0
# 4                       NJ   26006.0     39075.0
# 5                       NJ   26006.0     39075.0
# 6                       NJ   26006.0     39075.0
# 7                       NJ   26006.0     39075.0
# 8                       NJ   26006.0     39075.0
# 9                       NJ   69877.0     22141.0
# 10                      NJ       NaN         NaN
# 11                      NJ   56701.0     66719.0
# 12                      NJ  104452.0      8244.0
# 13                      NJ       NaN         NaN
# 14                      NJ       NaN         NaN
# 15                      NJ  150635.0      7792.0
# 16                      NJ       NaN         NaN
# 17                      NJ   91055.0      8390.0
# 18                      NJ  136125.0      4353.0
# 19                      NJ   91055.0      8390.0
# 20                      NJ  136125.0      4353.0
# 21                      NJ   85640.0     11808.0
# 22                      NJ   76250.0      3872.0
# 23                      NJ   85640.0     11808.0
# 24                      NJ   76250.0      3872.0
# 25                      NJ  129237.0     14683.0
# 26                      NJ  129237.0     14683.0
# 27                      NJ   73051.0     75118.0
# 28                      NJ  122684.0     45336.0
# 29                      NJ  122684.0     45336.0
# ..                     ...       ...         ...
# 313                     NJ  108333.0      5669.0
# 314                     NJ   79324.0     58499.0
# 315                     NJ  108333.0      5669.0
# 316                     NJ   79324.0     58499.0
# 317                     NJ  108333.0      5669.0
# 318                     NJ   79324.0     58499.0
# 319                     NJ  108333.0      5669.0
# 320                     NJ   79324.0     58499.0
# 321                     NJ  108333.0      5669.0
# 322                     NJ   90805.0     22572.0
# 323                     NJ   51113.0     60824.0
# 324                     NJ   85199.0     29386.0
# 325                     NJ  154647.0     15998.0
# 326                     NJ  121678.0      5961.0
# 327                     NJ  108092.0     55154.0
# 328                     NJ  108092.0     55154.0
# 329                     NJ  108092.0     55154.0
# 330                     NJ  108092.0     55154.0
# 331                     NJ  108092.0     55154.0
# 332                     NJ  108092.0     55154.0
# 333                     NJ  105931.0     10932.0
# 334                     NJ   50477.0     53345.0
# 335                     NJ  159923.0     30591.0
# 336                     NJ   95685.0     11246.0
# 337                     NJ   83266.0    101639.0
# 338                     NJ   83266.0    101639.0
# 339                     NJ   83266.0    101639.0
# 340                     NJ  161250.0      5868.0
# 341                     NJ  147463.0     17231.0
# 342                     NJ       NaN         NaN
#
# [343 rows x 10 columns]

# %%
starbucks_df = pd.read_csv("../Resources/merged-census.csv")
starbucks_df
# Out:
#                                     Name  Latitude  Longitude  \
# 0                               Galloway     39.46     -74.49
# 1                 Acme - Allendale #1095     41.03     -74.13
# 2                    Target Ocean T-1378     40.23     -74.05
# 3                Atlantic City, The Walk     39.36     -74.44
# 4            Golden Nugget-Atlantic City     39.38     -74.43
# 5                  Tropicana Marketplace     39.35     -74.45
# 6     Trump Taj Mahal-Atlantic City-Main     39.36     -74.42
# 7                  Acme - Barnegat #7921     39.76     -74.25
# 8                     Bernards-Riverwalk     40.65     -74.58
# 9             Stop & Shop - Bayonne #853     40.67     -74.11
# 10                 Village at Bedminster     40.65     -74.64
# 11              NJ Monmouth Travel Plaza     40.02     -74.27
# 12        Paramus Park Mall Center Court     40.96     -74.07
# 13                  Bernardsville Center     40.72     -74.56
# 14            Gloucester Premium Outlets     39.78     -75.05
# 15                  Acme - Boonton #1582     40.91     -74.40
# 16                            Bordentown     40.13     -74.72
# 17                            Branchburg     40.61     -74.69
# 18                    Whitehouse Station     40.62     -74.76
# 19                   Target Brick T-1153     40.06     -74.15
# 20         Bridgewater Mall-Level 1 Side     40.59     -74.62
# 21             Target Bridgewater T-1224     40.56     -74.56
# 22    The Village at Bridgewater Commons     40.58     -74.61
# 23              Target Burlington T-1158     40.04     -74.82
# 24        Rutgers U/Camden-Student Union     39.95     -75.12
# 25                  Cedar Knolls Hanover     40.81     -74.47
# 26                               Chatham     40.75     -74.43
# 27                      480 Evesham Road     39.86     -74.97
# 28              600 Route 38 Cherry Hill     39.94     -75.05
# 29                  Chapel & Haddonfield     39.93     -75.03
# ..                                   ...       ...        ...
# 217                    Ocean County Mall     39.98     -74.18
# 218          Stop & Shop-Toms River #811     39.95     -74.16
# 219                   Toms River Route 9     40.05     -74.22
# 220        Richard Stockton Travel Plaza     40.18     -74.64
# 221           5340 Route 42 Turnersville     39.76     -75.05
# 222           Target Turnersville T-1132     39.73     -75.04
# 223     Kean University-Thompson Library     40.68     -74.24
# 224               Rt. 22 - Center Island     40.69     -74.31
# 225                  Target Union T-2141     40.72     -74.29
# 226                  Acme - Vernon #2820     41.19     -74.49
# 227             Vineland Cumberland Mall     39.43     -75.04
# 228  Cedar Hill Shopping Center,Voorhees     39.84     -74.93
# 229                               Warren     40.62     -74.49
# 230                      Target Watchung     40.64     -74.41
# 231        Berdan Ave & Hamburg Turnpike     40.96     -74.24
# 232                 Macy's - Willowbrook     40.89     -74.26
# 233        Paterson-Hamburg Tpke - Wayne     40.94     -74.20
# 234                         Wayne Rt. 23     40.95     -74.27
# 235                Wayne West Belt Plaza     40.89     -74.25
# 236          Willowbrook Mall Food Court     40.89     -74.26
# 237                        West Caldwell     40.85     -74.30
# 238                        West New York     40.78     -74.01
# 239                            Westfield     40.65     -74.35
# 240                      Westwood Avenue     40.99     -74.03
# 241     NJ Grover Cleveland Travel Plaza     40.56     -74.26
# 242            Thomas Edison Travel Plza     40.56     -74.27
# 243                      Woodbridge Mall     40.56     -74.30
# 244          Acme - Woodcliff Lake #1069     41.04     -74.07
# 245                              Wyckoff     41.01     -74.17
# 246     Woodrow Wilson Travel Plaza - N6     40.18     -74.63
#
#                                    Street1       Street2  \
# 0                       405 S. Pitney Road           NaN
# 1                         45 Demercurio Dr           NaN
# 2                      2331 State Route 66           NaN
# 3                120 North Michigan Avenue           NaN
# 4                            1 Castle Blvd           NaN
# 5                           2831 Boardwalk           NaN
# 6           1000 Boardwalk at Virginia Ave           NaN
# 7                            912 W Bay Ave           NaN
# 8                    655 Martinsville Road           NaN
# 9                            1 Lefante Way           NaN
# 10                  432 US Highway 202/206           NaN
# 11      Garden State Pkwy, Mile Marker 100           NaN
# 12                        700 Paramus Park           NaN
# 13                       80 Morristown Rd.       Unit 10
# 14                 1125 S Black Horse Pike     Space 575
# 15                       550 Myrtle Avenue           NaN
# 16                     282 Dunns Mill Road           NaN
# 17        240 Raritan Valley College Drive           NaN
# 18                    531 Route 22 East #8           NaN
# 19                        570 Rte. 70 West           NaN
# 20                         400 Commons Way          2475
# 21                      200 Promenade Blvd           NaN
# 22                    610 Commons Way 4300           NaN
# 23                          2703 Route 541           NaN
# 24                             326 Penn St           NaN
# 25                      178 Hanover Avenue           101
# 26                        640 Shunpike Rd.           NaN
# 27                        480 Evesham Road           NaN
# 28                               600 Rt 38           NaN
# 29                    512 Haddonfield Road           NaN
# ..                                     ...           ...
# 217                        1201 HOOPER AVE          1072
# 218                      353 Route 37 East           NaN
# 219                       2360 Lakewood Rd           NaN
# 220                     200 Uncle Petes Rd           NaN
# 221                          5340 Route 42           NaN
# 222                  4001 Black Horse Pike           NaN
# 223                        1000 Morris Ave           NaN
# 224                     2698 Route 22 East           NaN
# 225                   2235 Springfield Ave           NaN
# 226                             530 CR-515           NaN
# 227                    3849 S. Delsea Road  Space #A0013
# 228                           148 Route 73           NaN
# 229                      4 Mount Bethel Rd           NaN
# 230                     1515 US Highway 22           NaN
# 231                  1118 Hamburg Turnpike           NaN
# 232                  1100 Willowbrook Blvd           NaN
# 233                   183 Hamburg Turnpike           NaN
# 234                    1606 Route 23 North           NaN
# 235                      57 state route 23           NaN
# 236                  1400 Willowbrook Mall           NaN
# 237                       546 Passaic Ave.           NaN
# 238                   55-1 Riverwalk Place           NaN
# 239                     117 Central Avenue           NaN
# 240                    102 Westwood Avenue           104
# 241                       Mile Marker 92.9           NaN
# 242  New Jersey Turnpike, Mile Post 92.9 S           NaN
# 243            250 Woodbridge Center Drive           NaN
# 244                  520 Chestnut Ridge Rd           NaN
# 245                    325 Franklin Avenue           NaN
# 246      Mile post 57.8-North, NJ Turnpike           NaN
#
#                                      Street3            City  \
# 0    Galloway Village Square Shopping Center         Absecon
# 1                                        NaN       Allendale
# 2                                        NaN     Asbury Park
# 3                                        NaN   Atlantic City
# 4                                        NaN   Atlantic City
# 5                                        NaN   Atlantic City
# 6                                        NaN   Atlantic City
# 7                                        NaN        Barnegat
# 8                                        NaN   Basking Ridge
# 9                                        NaN         Bayonne
# 10                     Village at Bedminster      Bedminster
# 11                                       NaN         Bellmar
# 12                                       NaN          Bergen
# 13                                       NaN   Bernardsville
# 14                                       NaN       Blackwood
# 15                                       NaN         Boonton
# 16                ACME Commons at Bordentown      Bordentown
# 17                     Shoppes at Branchburg      Branchburg
# 18                                       NaN      Branchburg
# 19                                       NaN           Brick
# 20                       Bridgewater Commons     Bridgewater
# 21                                       NaN     Bridgewater
# 22        The Village at Bridgewater Commons     Bridgewater
# 23                                       NaN      Burlington
# 24                                       NaN          Camden
# 25                                       NaN    Cedar Knolls
# 26                                       NaN         Chatham
# 27                  Short Hills Towne Centre     Cherry Hill
# 28                                       NaN     Cherry Hill
# 29                                       NaN     Cherry Hill
# ..                                       ...             ...
# 217                        Ocean County Mall      Toms River
# 218                                      NaN      Toms River
# 219                                      NaN      Toms River
# 220                                      NaN         Trenton
# 221                                      NaN    Turnersville
# 222                                      NaN    Turnersville
# 223                                      NaN           Union
# 224                                      NaN           Union
# 225                                      NaN           Union
# 226                                      NaN          Vernon
# 227                          Cumberland Mall        Vineland
# 228               Cedar Hill Shopping Center        Voorhees
# 229                                      NaN          Warren
# 230                                      NaN        Watchung
# 231                                      NaN           Wayne
# 232                         Willowbrook Mall           Wayne
# 233                                      NaN           Wayne
# 234                                      NaN           Wayne
# 235                                      NaN           Wayne
# 236                         Willowbrook Mall           Wayne
# 237                                      NaN   West Caldwell
# 238                                      NaN   West New York
# 239                                      NaN       Westfield
# 240                          Meisel Building        Westwood
# 241                                      NaN      Woodbridge
# 242                                      NaN      Woodbridge
# 243                        Woodbridge Center      Woodbridge
# 244                                      NaN  Woodcliff Lake
# 245                                      NaN         Wyckoff
# 246                                      NaN       Yardville
#
#     CountrySubdivisionCode    Income  Population
# 0                       NJ   63887.0      8370.0
# 1                       NJ  151875.0      6820.0
# 2                       NJ   39324.0     15830.0
# 3                       NJ   26006.0     39075.0
# 4                       NJ   26006.0     39075.0
# 5                       NJ   26006.0     39075.0
# 6                       NJ   26006.0     39075.0
# 7                       NJ   69877.0     22141.0
# 8                       NJ       NaN         NaN
# 9                       NJ   56701.0     66719.0
# 10                      NJ  104452.0      8244.0
# 11                      NJ       NaN         NaN
# 12                      NJ       NaN         NaN
# 13                      NJ  150635.0      7792.0
# 14                      NJ       NaN         NaN
# 15                      NJ   91055.0      8390.0
# 16                      NJ   85640.0     11808.0
# 17                      NJ  129237.0     14683.0
# 18                      NJ  129237.0     14683.0
# 19                      NJ   73051.0     75118.0
# 20                      NJ  122684.0     45336.0
# 21                      NJ  122684.0     45336.0
# 22                      NJ  122684.0     45336.0
# 23                      NJ   50709.0      9835.0
# 24                      NJ   26105.0     75550.0
# 25                      NJ       NaN         NaN
# 26                      NJ  176364.0     10507.0
# 27                      NJ   97069.0     71204.0
# 28                      NJ   97069.0     71204.0
# 29                      NJ   97069.0     71204.0
# ..                     ...       ...         ...
# 217                     NJ   76051.0     91415.0
# 218                     NJ   76051.0     91415.0
# 219                     NJ   76051.0     91415.0
# 220                     NJ   35524.0     84867.0
# 221                     NJ       NaN         NaN
# 222                     NJ       NaN         NaN
# 223                     NJ   79324.0     58499.0
# 224                     NJ   79324.0     58499.0
# 225                     NJ   79324.0     58499.0
# 226                     NJ   90805.0     22572.0
# 227                     NJ   51113.0     60824.0
# 228                     NJ   85199.0     29386.0
# 229                     NJ  154647.0     15998.0
# 230                     NJ  121678.0      5961.0
# 231                     NJ  108092.0     55154.0
# 232                     NJ  108092.0     55154.0
# 233                     NJ  108092.0     55154.0
# 234                     NJ  108092.0     55154.0
# 235                     NJ  108092.0     55154.0
# 236                     NJ  108092.0     55154.0
# 237                     NJ  105931.0     10932.0
# 238                     NJ   50477.0     53345.0
# 239                     NJ  159923.0     30591.0
# 240                     NJ   95685.0     11246.0
# 241                     NJ   83266.0    101639.0
# 242                     NJ   83266.0    101639.0
# 243                     NJ   83266.0    101639.0
# 244                     NJ  161250.0      5868.0
# 245                     NJ  147463.0     17231.0
# 246                     NJ       NaN         NaN
#
# [247 rows x 10 columns]

# %%
starbucks_df['City'].unique()
# Out:
# array(['Absecon', 'Allendale', 'Asbury Park', 'Atlantic City', 'Barnegat',
#        'Basking Ridge', 'Bayonne', 'Bedminster', 'Bellmar', 'Bergen',
#        'Bernardsville', 'Blackwood', 'Boonton', 'Bordentown',
#        'Branchburg', 'Brick', 'Bridgewater', 'Burlington', 'Camden',
#        'Cedar Knolls', 'Chatham', 'Cherry Hill', 'Chester', 'Clark',
#        'Clementon', 'Clifton', 'Closter', 'CLOSTER', 'Cranbury',
#        'Cranford', 'Delran', 'Denville', 'Deptford', 'East Brunswick',
#        'East Hanover', 'East Ridgefield', 'East Rutherford', 'Eatontown',
#        'Edgewater', 'Edison', 'Elizabeth', 'Englewood', 'Evesham',
#        'Fairfield', 'Fairlawn', 'Flemington', 'Florham Park',
#        'Forked River', 'Fort Lee', 'Franklin', 'Franklin Lakes',
#        'Franklin Park', 'Freehold', 'Galloway', 'Gillette', 'Glen Ridge',
#        'Glen Rock', 'Green Brook', 'Hackensack', 'Hackettstown',
#        'Haddonfield', 'Hamilton', 'Hammonton', 'Hasbrouck Heights',
#        'Hillsborough', 'Hillsdale', 'Hoboken', 'Howell', 'Iselin',
#        'Jersey City', 'Kenilworth', 'Lakewood', 'Lawrenceville',
#        'Lincroft', 'Linden', 'Little Ferry', 'Livingston', 'Madison',
#        'Mahwah', 'Manahawkin', 'Manalapan', 'Margate City', 'Matawan',
#        'Mays Landing', 'Medford', 'Middletown', 'Midland Park',
#        'Millburn', 'Milltown', 'Millville', 'Montclair', 'Montvale',
#        'Moorestown', 'Morganville', 'Morris Plains', 'Morristown',
#        'Mount Laurel', 'Neptune', 'New Brunswick', 'New Providence',
#        'Newark', 'North Bergen', 'North Brunswick', 'Northvale', 'Nutley',
#        'Oakhurst', 'Oakland', 'Ocean City', 'Old Bridge', 'Old Tappan',
#        'Paramus', 'Park Ridge', 'Pennington', 'Penns Grove', 'Pennsgrove',
#        'Phillipsburg', 'Piscataway', 'Pomona', 'Pompton Lakes',
#        'Princeton', 'Ramsey', 'Red Bank', 'Ridgewood', 'Rio Grande',
#        'Riverdale', 'Riverside', 'Rockaway', 'Roseland', 'Rutherford',
#        'Sea Girt', 'Secaucus', 'Sewell', 'Shorthills', 'Shrewsbury',
#        'Sicklerville', 'Somers Point', 'Somerset', 'Somerville',
#        'South Amboy', 'South Brunswick', 'South Orange',
#        'South Plainfield', 'Spring Lake', 'Summit', 'Tinton Falls',
#        'Toms River', 'Trenton', 'Turnersville', 'Union', 'Vernon',
#        'Vineland', 'Voorhees', 'Warren', 'Watchung', 'Wayne',
#        'West Caldwell', 'West New York', 'Westfield', 'Westwood',
#        'Woodbridge', 'Woodcliff Lake', 'Wyckoff', 'Yardville'],
#       dtype=object)

# %%
starbucks_df['City'].value_counts()
# Out:
# Cherry Hill       8
# Wayne             6
# Edison            5
# Fort Lee          5
# Paramus           5
# Jersey City       5
# Freehold          4
# Atlantic City     4
# Newark            4
# Mount Laurel      4
# Lawrenceville     4
# Phillipsburg      3
# Rockaway          3
# Union             3
# Hoboken           3
# Toms River        3
# Woodbridge        3
# Cranbury          3
# Bridgewater       3
# Piscataway        3
# Moorestown        2
# Cranford          2
# South Amboy       2
# Ridgewood         2
# Edgewater         2
# Denville          2
# New Brunswick     2
# Hackettstown      2
# Sewell            2
# Morristown        2
#                  ..
# Mahwah            1
# Forked River      1
# Elizabeth         1
# Glen Ridge        1
# Westfield         1
# Old Bridge        1
# Midland Park      1
# Matawan           1
# Riverside         1
# Millburn          1
# Boonton           1
# Bayonne           1
# West Caldwell     1
# Absecon           1
# Gillette          1
# Warren            1
# Oakhurst          1
# Pennington        1
# Brick             1
# Florham Park      1
# Linden            1
# Woodcliff Lake    1
# South Orange      1
# Hamilton          1
# Somerville        1
# Medford           1
# Bernardsville     1
# Hillsborough      1
# Ocean City        1
# Morris Plains     1
# Name: City, Length: 163, dtype: int64

# %%
#Google Maps/Places API section

from config import gkey

# %%
starbucks_df['lat-API'] = ""
starbucks_df['long-API'] = ""
starbucks_df['target search add'] = ""

starbucks_df.head()
# Out:
#                           Name  Latitude  Longitude  \
# 0                     Galloway     39.46     -74.49
# 1       Acme - Allendale #1095     41.03     -74.13
# 2          Target Ocean T-1378     40.23     -74.05
# 3      Atlantic City, The Walk     39.36     -74.44
# 4  Golden Nugget-Atlantic City     39.38     -74.43
#
#                      Street1 Street2                                  Street3  \
# 0         405 S. Pitney Road     NaN  Galloway Village Square Shopping Center
# 1           45 Demercurio Dr     NaN                                      NaN
# 2        2331 State Route 66     NaN                                      NaN
# 3  120 North Michigan Avenue     NaN                                      NaN
# 4              1 Castle Blvd     NaN                                      NaN
#
#             City CountrySubdivisionCode    Income  Population lat-API  \
# 0        Absecon                     NJ   63887.0      8370.0
# 1      Allendale                     NJ  151875.0      6820.0
# 2    Asbury Park                     NJ   39324.0     15830.0
# 3  Atlantic City                     NJ   26006.0     39075.0
# 4  Atlantic City                     NJ   26006.0     39075.0
#
#   long-API target search add
# 0
# 1
# 2
# 3
# 4

# %%
# use iterrows to iterate through pandas dataframe
for index, row in starbucks_df.iterrows():
    starbucks_df['target search add'] = starbucks_df['Street1'] + "," + starbucks_df['City'] + "," + starbucks_df['CountrySubdivisionCode']
    
starbucks_df
# Out:
#                                     Name  Latitude  Longitude  \
# 0                               Galloway     39.46     -74.49
# 1                 Acme - Allendale #1095     41.03     -74.13
# 2                    Target Ocean T-1378     40.23     -74.05
# 3                Atlantic City, The Walk     39.36     -74.44
# 4            Golden Nugget-Atlantic City     39.38     -74.43
# 5                  Tropicana Marketplace     39.35     -74.45
# 6     Trump Taj Mahal-Atlantic City-Main     39.36     -74.42
# 7                  Acme - Barnegat #7921     39.76     -74.25
# 8                     Bernards-Riverwalk     40.65     -74.58
# 9             Stop & Shop - Bayonne #853     40.67     -74.11
# 10                 Village at Bedminster     40.65     -74.64
# 11              NJ Monmouth Travel Plaza     40.02     -74.27
# 12        Paramus Park Mall Center Court     40.96     -74.07
# 13                  Bernardsville Center     40.72     -74.56
# 14            Gloucester Premium Outlets     39.78     -75.05
# 15                  Acme - Boonton #1582     40.91     -74.40
# 16                            Bordentown     40.13     -74.72
# 17                            Branchburg     40.61     -74.69
# 18                    Whitehouse Station     40.62     -74.76
# 19                   Target Brick T-1153     40.06     -74.15
# 20         Bridgewater Mall-Level 1 Side     40.59     -74.62
# 21             Target Bridgewater T-1224     40.56     -74.56
# 22    The Village at Bridgewater Commons     40.58     -74.61
# 23              Target Burlington T-1158     40.04     -74.82
# 24        Rutgers U/Camden-Student Union     39.95     -75.12
# 25                  Cedar Knolls Hanover     40.81     -74.47
# 26                               Chatham     40.75     -74.43
# 27                      480 Evesham Road     39.86     -74.97
# 28              600 Route 38 Cherry Hill     39.94     -75.05
# 29                  Chapel & Haddonfield     39.93     -75.03
# ..                                   ...       ...        ...
# 217                    Ocean County Mall     39.98     -74.18
# 218          Stop & Shop-Toms River #811     39.95     -74.16
# 219                   Toms River Route 9     40.05     -74.22
# 220        Richard Stockton Travel Plaza     40.18     -74.64
# 221           5340 Route 42 Turnersville     39.76     -75.05
# 222           Target Turnersville T-1132     39.73     -75.04
# 223     Kean University-Thompson Library     40.68     -74.24
# 224               Rt. 22 - Center Island     40.69     -74.31
# 225                  Target Union T-2141     40.72     -74.29
# 226                  Acme - Vernon #2820     41.19     -74.49
# 227             Vineland Cumberland Mall     39.43     -75.04
# 228  Cedar Hill Shopping Center,Voorhees     39.84     -74.93
# 229                               Warren     40.62     -74.49
# 230                      Target Watchung     40.64     -74.41
# 231        Berdan Ave & Hamburg Turnpike     40.96     -74.24
# 232                 Macy's - Willowbrook     40.89     -74.26
# 233        Paterson-Hamburg Tpke - Wayne     40.94     -74.20
# 234                         Wayne Rt. 23     40.95     -74.27
# 235                Wayne West Belt Plaza     40.89     -74.25
# 236          Willowbrook Mall Food Court     40.89     -74.26
# 237                        West Caldwell     40.85     -74.30
# 238                        West New York     40.78     -74.01
# 239                            Westfield     40.65     -74.35
# 240                      Westwood Avenue     40.99     -74.03
# 241     NJ Grover Cleveland Travel Plaza     40.56     -74.26
# 242            Thomas Edison Travel Plza     40.56     -74.27
# 243                      Woodbridge Mall     40.56     -74.30
# 244          Acme - Woodcliff Lake #1069     41.04     -74.07
# 245                              Wyckoff     41.01     -74.17
# 246     Woodrow Wilson Travel Plaza - N6     40.18     -74.63
#
#                                    Street1       Street2  \
# 0                       405 S. Pitney Road           NaN
# 1                         45 Demercurio Dr           NaN
# 2                      2331 State Route 66           NaN
# 3                120 North Michigan Avenue           NaN
# 4                            1 Castle Blvd           NaN
# 5                           2831 Boardwalk           NaN
# 6           1000 Boardwalk at Virginia Ave           NaN
# 7                            912 W Bay Ave           NaN
# 8                    655 Martinsville Road           NaN
# 9                            1 Lefante Way           NaN
# 10                  432 US Highway 202/206           NaN
# 11      Garden State Pkwy, Mile Marker 100           NaN
# 12                        700 Paramus Park           NaN
# 13                       80 Morristown Rd.       Unit 10
# 14                 1125 S Black Horse Pike     Space 575
# 15                       550 Myrtle Avenue           NaN
# 16                     282 Dunns Mill Road           NaN
# 17        240 Raritan Valley College Drive           NaN
# 18                    531 Route 22 East #8           NaN
# 19                        570 Rte. 70 West           NaN
# 20                         400 Commons Way          2475
# 21                      200 Promenade Blvd           NaN
# 22                    610 Commons Way 4300           NaN
# 23                          2703 Route 541           NaN
# 24                             326 Penn St           NaN
# 25                      178 Hanover Avenue           101
# 26                        640 Shunpike Rd.           NaN
# 27                        480 Evesham Road           NaN
# 28                               600 Rt 38           NaN
# 29                    512 Haddonfield Road           NaN
# ..                                     ...           ...
# 217                        1201 HOOPER AVE          1072
# 218                      353 Route 37 East           NaN
# 219                       2360 Lakewood Rd           NaN
# 220                     200 Uncle Petes Rd           NaN
# 221                          5340 Route 42           NaN
# 222                  4001 Black Horse Pike           NaN
# 223                        1000 Morris Ave           NaN
# 224                     2698 Route 22 East           NaN
# 225                   2235 Springfield Ave           NaN
# 226                             530 CR-515           NaN
# 227                    3849 S. Delsea Road  Space #A0013
# 228                           148 Route 73           NaN
# 229                      4 Mount Bethel Rd           NaN
# 230                     1515 US Highway 22           NaN
# 231                  1118 Hamburg Turnpike           NaN
# 232                  1100 Willowbrook Blvd           NaN
# 233                   183 Hamburg Turnpike           NaN
# 234                    1606 Route 23 North           NaN
# 235                      57 state route 23           NaN
# 236                  1400 Willowbrook Mall           NaN
# 237                       546 Passaic Ave.           NaN
# 238                   55-1 Riverwalk Place           NaN
# 239                     117 Central Avenue           NaN
# 240                    102 Westwood Avenue           104
# 241                       Mile Marker 92.9           NaN
# 242  New Jersey Turnpike, Mile Post 92.9 S           NaN
# 243            250 Woodbridge Center Drive           NaN
# 244                  520 Chestnut Ridge Rd           NaN
# 245                    325 Franklin Avenue           NaN
# 246      Mile post 57.8-North, NJ Turnpike           NaN
#
#                                      Street3            City  \
# 0    Galloway Village Square Shopping Center         Absecon
# 1                                        NaN       Allendale
# 2                                        NaN     Asbury Park
# 3                                        NaN   Atlantic City
# 4                                        NaN   Atlantic City
# 5                                        NaN   Atlantic City
# 6                                        NaN   Atlantic City
# 7                                        NaN        Barnegat
# 8                                        NaN   Basking Ridge
# 9                                        NaN         Bayonne
# 10                     Village at Bedminster      Bedminster
# 11                                       NaN         Bellmar
# 12                                       NaN          Bergen
# 13                                       NaN   Bernardsville
# 14                                       NaN       Blackwood
# 15                                       NaN         Boonton
# 16                ACME Commons at Bordentown      Bordentown
# 17                     Shoppes at Branchburg      Branchburg
# 18                                       NaN      Branchburg
# 19                                       NaN           Brick
# 20                       Bridgewater Commons     Bridgewater
# 21                                       NaN     Bridgewater
# 22        The Village at Bridgewater Commons     Bridgewater
# 23                                       NaN      Burlington
# 24                                       NaN          Camden
# 25                                       NaN    Cedar Knolls
# 26                                       NaN         Chatham
# 27                  Short Hills Towne Centre     Cherry Hill
# 28                                       NaN     Cherry Hill
# 29                                       NaN     Cherry Hill
# ..                                       ...             ...
# 217                        Ocean County Mall      Toms River
# 218                                      NaN      Toms River
# 219                                      NaN      Toms River
# 220                                      NaN         Trenton
# 221                                      NaN    Turnersville
# 222                                      NaN    Turnersville
# 223                                      NaN           Union
# 224                                      NaN           Union
# 225                                      NaN           Union
# 226                                      NaN          Vernon
# 227                          Cumberland Mall        Vineland
# 228               Cedar Hill Shopping Center        Voorhees
# 229                                      NaN          Warren
# 230                                      NaN        Watchung
# 231                                      NaN           Wayne
# 232                         Willowbrook Mall           Wayne
# 233                                      NaN           Wayne
# 234                                      NaN           Wayne
# 235                                      NaN           Wayne
# 236                         Willowbrook Mall           Wayne
# 237                                      NaN   West Caldwell
# 238                                      NaN   West New York
# 239                                      NaN       Westfield
# 240                          Meisel Building        Westwood
# 241                                      NaN      Woodbridge
# 242                                      NaN      Woodbridge
# 243                        Woodbridge Center      Woodbridge
# 244                                      NaN  Woodcliff Lake
# 245                                      NaN         Wyckoff
# 246                                      NaN       Yardville
#
#     CountrySubdivisionCode    Income  Population lat-API long-API  \
# 0                       NJ   63887.0      8370.0
# 1                       NJ  151875.0      6820.0
# 2                       NJ   39324.0     15830.0
# 3                       NJ   26006.0     39075.0
# 4                       NJ   26006.0     39075.0
# 5                       NJ   26006.0     39075.0
# 6                       NJ   26006.0     39075.0
# 7                       NJ   69877.0     22141.0
# 8                       NJ       NaN         NaN
# 9                       NJ   56701.0     66719.0
# 10                      NJ  104452.0      8244.0
# 11                      NJ       NaN         NaN
# 12                      NJ       NaN         NaN
# 13                      NJ  150635.0      7792.0
# 14                      NJ       NaN         NaN
# 15                      NJ   91055.0      8390.0
# 16                      NJ   85640.0     11808.0
# 17                      NJ  129237.0     14683.0
# 18                      NJ  129237.0     14683.0
# 19                      NJ   73051.0     75118.0
# 20                      NJ  122684.0     45336.0
# 21                      NJ  122684.0     45336.0
# 22                      NJ  122684.0     45336.0
# 23                      NJ   50709.0      9835.0
# 24                      NJ   26105.0     75550.0
# 25                      NJ       NaN         NaN
# 26                      NJ  176364.0     10507.0
# 27                      NJ   97069.0     71204.0
# 28                      NJ   97069.0     71204.0
# 29                      NJ   97069.0     71204.0
# ..                     ...       ...         ...     ...      ...
# 217                     NJ   76051.0     91415.0
# 218                     NJ   76051.0     91415.0
# 219                     NJ   76051.0     91415.0
# 220                     NJ   35524.0     84867.0
# 221                     NJ       NaN         NaN
# 222                     NJ       NaN         NaN
# 223                     NJ   79324.0     58499.0
# 224                     NJ   79324.0     58499.0
# 225                     NJ   79324.0     58499.0
# 226                     NJ   90805.0     22572.0
# 227                     NJ   51113.0     60824.0
# 228                     NJ   85199.0     29386.0
# 229                     NJ  154647.0     15998.0
# 230                     NJ  121678.0      5961.0
# 231                     NJ  108092.0     55154.0
# 232                     NJ  108092.0     55154.0
# 233                     NJ  108092.0     55154.0
# 234                     NJ  108092.0     55154.0
# 235                     NJ  108092.0     55154.0
# 236                     NJ  108092.0     55154.0
# 237                     NJ  105931.0     10932.0
# 238                     NJ   50477.0     53345.0
# 239                     NJ  159923.0     30591.0
# 240                     NJ   95685.0     11246.0
# 241                     NJ   83266.0    101639.0
# 242                     NJ   83266.0    101639.0
# 243                     NJ   83266.0    101639.0
# 244                     NJ  161250.0      5868.0
# 245                     NJ  147463.0     17231.0
# 246                     NJ       NaN         NaN
#
#                                      target search add
# 0                        405 S. Pitney Road,Absecon,NJ
# 1                        45 Demercurio Dr,Allendale,NJ
# 2                   2331 State Route 66,Asbury Park,NJ
# 3           120 North Michigan Avenue,Atlantic City,NJ
# 4                       1 Castle Blvd,Atlantic City,NJ
# 5                      2831 Boardwalk,Atlantic City,NJ
# 6      1000 Boardwalk at Virginia Ave,Atlantic City,NJ
# 7                            912 W Bay Ave,Barnegat,NJ
# 8               655 Martinsville Road,Basking Ridge,NJ
# 9                             1 Lefante Way,Bayonne,NJ
# 10                432 US Highway 202/206,Bedminster,NJ
# 11       Garden State Pkwy, Mile Marker 100,Bellmar,NJ
# 12                          700 Paramus Park,Bergen,NJ
# 13                  80 Morristown Rd.,Bernardsville,NJ
# 14                1125 S Black Horse Pike,Blackwood,NJ
# 15                        550 Myrtle Avenue,Boonton,NJ
# 16                   282 Dunns Mill Road,Bordentown,NJ
# 17      240 Raritan Valley College Drive,Branchburg,NJ
# 18                  531 Route 22 East #8,Branchburg,NJ
# 19                           570 Rte. 70 West,Brick,NJ
# 20                      400 Commons Way,Bridgewater,NJ
# 21                   200 Promenade Blvd,Bridgewater,NJ
# 22                 610 Commons Way 4300,Bridgewater,NJ
# 23                        2703 Route 541,Burlington,NJ
# 24                               326 Penn St,Camden,NJ
# 25                  178 Hanover Avenue,Cedar Knolls,NJ
# 26                         640 Shunpike Rd.,Chatham,NJ
# 27                     480 Evesham Road,Cherry Hill,NJ
# 28                            600 Rt 38,Cherry Hill,NJ
# 29                 512 Haddonfield Road,Cherry Hill,NJ
# ..                                                 ...
# 217                      1201 HOOPER AVE,Toms River,NJ
# 218                    353 Route 37 East,Toms River,NJ
# 219                     2360 Lakewood Rd,Toms River,NJ
# 220                      200 Uncle Petes Rd,Trenton,NJ
# 221                      5340 Route 42,Turnersville,NJ
# 222              4001 Black Horse Pike,Turnersville,NJ
# 223                           1000 Morris Ave,Union,NJ
# 224                        2698 Route 22 East,Union,NJ
# 225                      2235 Springfield Ave,Union,NJ
# 226                               530 CR-515,Vernon,NJ
# 227                    3849 S. Delsea Road,Vineland,NJ
# 228                           148 Route 73,Voorhees,NJ
# 229                        4 Mount Bethel Rd,Warren,NJ
# 230                     1515 US Highway 22,Watchung,NJ
# 231                     1118 Hamburg Turnpike,Wayne,NJ
# 232                     1100 Willowbrook Blvd,Wayne,NJ
# 233                      183 Hamburg Turnpike,Wayne,NJ
# 234                       1606 Route 23 North,Wayne,NJ
# 235                         57 state route 23,Wayne,NJ
# 236                     1400 Willowbrook Mall,Wayne,NJ
# 237                  546 Passaic Ave.,West Caldwell,NJ
# 238              55-1 Riverwalk Place,West New York,NJ
# 239                    117 Central Avenue,Westfield,NJ
# 240                    102 Westwood Avenue,Westwood,NJ
# 241                     Mile Marker 92.9,Woodbridge,NJ
# 242  New Jersey Turnpike, Mile Post 92.9 S,Woodbrid...
# 243          250 Woodbridge Center Drive,Woodbridge,NJ
# 244            520 Chestnut Ridge Rd,Woodcliff Lake,NJ
# 245                     325 Franklin Avenue,Wyckoff,NJ
# 246     Mile post 57.8-North, NJ Turnpike,Yardville,NJ
#
# [247 rows x 13 columns]

# %%
# use iterrows to iterate through pandas dataframe
for index, row in starbucks_df.iterrows():
    
    try:

        # Target address
        target_address = row['target search add']

        # Build the endpoint URL
        target_url = ('https://maps.googleapis.com/maps/api/geocode/json?'
        'address={0}&key={1}').format(target_address, gkey)

        geo_data = requests.get(target_url).json()
        lat = geo_data["results"][0]["geometry"]["location"]["lat"]
        lng = geo_data["results"][0]["geometry"]["location"]["lng"]

        starbucks_df.loc[index, 'lat-API'] = lat
        starbucks_df.loc[index, 'long-API'] = lng
    except: 
        print("error " + str(index))
# Out:
# error 18

# %%
starbucks_df
# Out:
#                                     Name  \
# 0                               Galloway
# 1                 Acme - Allendale #1095
# 2                    Target Ocean T-1378
# 3                Atlantic City, The Walk
# 4            Golden Nugget-Atlantic City
# 5                  Tropicana Marketplace
# 6     Trump Taj Mahal-Atlantic City-Main
# 7                  Acme - Barnegat #7921
# 8                     Bernards-Riverwalk
# 9             Stop & Shop - Bayonne #853
# 10                 Village at Bedminster
# 11              NJ Monmouth Travel Plaza
# 12        Paramus Park Mall Center Court
# 13                  Bernardsville Center
# 14            Gloucester Premium Outlets
# 15                  Acme - Boonton #1582
# 16                            Bordentown
# 17                            Branchburg
# 18                    Whitehouse Station
# 19                   Target Brick T-1153
# 20         Bridgewater Mall-Level 1 Side
# 21             Target Bridgewater T-1224
# 22    The Village at Bridgewater Commons
# 23              Target Burlington T-1158
# 24        Rutgers U/Camden-Student Union
# 25                  Cedar Knolls Hanover
# 26                               Chatham
# 27                      480 Evesham Road
# 28              600 Route 38 Cherry Hill
# 29                  Chapel & Haddonfield
# ..                                   ...
# 217                    Ocean County Mall
# 218          Stop & Shop-Toms River #811
# 219                   Toms River Route 9
# 220        Richard Stockton Travel Plaza
# 221           5340 Route 42 Turnersville
# 222           Target Turnersville T-1132
# 223     Kean University-Thompson Library
# 224               Rt. 22 - Center Island
# 225                  Target Union T-2141
# 226                  Acme - Vernon #2820
# 227             Vineland Cumberland Mall
# 228  Cedar Hill Shopping Center,Voorhees
# 229                               Warren
# 230                      Target Watchung
# 231        Berdan Ave & Hamburg Turnpike
# 232                 Macy's - Willowbrook
# 233        Paterson-Hamburg Tpke - Wayne
# 234                         Wayne Rt. 23
# 235                Wayne West Belt Plaza
# 236          Willowbrook Mall Food Court
# 237                        West Caldwell
# 238                        West New York
# 239                            Westfield
# 240                      Westwood Avenue
# 241     NJ Grover Cleveland Travel Plaza
# 242            Thomas Edison Travel Plza
# 243                      Woodbridge Mall
# 244          Acme - Woodcliff Lake #1069
# 245                              Wyckoff
# 246     Woodrow Wilson Travel Plaza - N6
#
#                                    Street1       Street2  \
# 0                       405 S. Pitney Road           NaN
# 1                         45 Demercurio Dr           NaN
# 2                      2331 State Route 66           NaN
# 3                120 North Michigan Avenue           NaN
# 4                            1 Castle Blvd           NaN
# 5                           2831 Boardwalk           NaN
# 6           1000 Boardwalk at Virginia Ave           NaN
# 7                            912 W Bay Ave           NaN
# 8                    655 Martinsville Road           NaN
# 9                            1 Lefante Way           NaN
# 10                  432 US Highway 202/206           NaN
# 11      Garden State Pkwy, Mile Marker 100           NaN
# 12                        700 Paramus Park           NaN
# 13                       80 Morristown Rd.       Unit 10
# 14                 1125 S Black Horse Pike     Space 575
# 15                       550 Myrtle Avenue           NaN
# 16                     282 Dunns Mill Road           NaN
# 17        240 Raritan Valley College Drive           NaN
# 18                    531 Route 22 East #8           NaN
# 19                        570 Rte. 70 West           NaN
# 20                         400 Commons Way          2475
# 21                      200 Promenade Blvd           NaN
# 22                    610 Commons Way 4300           NaN
# 23                          2703 Route 541           NaN
# 24                             326 Penn St           NaN
# 25                      178 Hanover Avenue           101
# 26                        640 Shunpike Rd.           NaN
# 27                        480 Evesham Road           NaN
# 28                               600 Rt 38           NaN
# 29                    512 Haddonfield Road           NaN
# ..                                     ...           ...
# 217                        1201 HOOPER AVE          1072
# 218                      353 Route 37 East           NaN
# 219                       2360 Lakewood Rd           NaN
# 220                     200 Uncle Petes Rd           NaN
# 221                          5340 Route 42           NaN
# 222                  4001 Black Horse Pike           NaN
# 223                        1000 Morris Ave           NaN
# 224                     2698 Route 22 East           NaN
# 225                   2235 Springfield Ave           NaN
# 226                             530 CR-515           NaN
# 227                    3849 S. Delsea Road  Space #A0013
# 228                           148 Route 73           NaN
# 229                      4 Mount Bethel Rd           NaN
# 230                     1515 US Highway 22           NaN
# 231                  1118 Hamburg Turnpike           NaN
# 232                  1100 Willowbrook Blvd           NaN
# 233                   183 Hamburg Turnpike           NaN
# 234                    1606 Route 23 North           NaN
# 235                      57 state route 23           NaN
# 236                  1400 Willowbrook Mall           NaN
# 237                       546 Passaic Ave.           NaN
# 238                   55-1 Riverwalk Place           NaN
# 239                     117 Central Avenue           NaN
# 240                    102 Westwood Avenue           104
# 241                       Mile Marker 92.9           NaN
# 242  New Jersey Turnpike, Mile Post 92.9 S           NaN
# 243            250 Woodbridge Center Drive           NaN
# 244                  520 Chestnut Ridge Rd           NaN
# 245                    325 Franklin Avenue           NaN
# 246      Mile post 57.8-North, NJ Turnpike           NaN
#
#                                      Street3            City  \
# 0    Galloway Village Square Shopping Center         Absecon
# 1                                        NaN       Allendale
# 2                                        NaN     Asbury Park
# 3                                        NaN   Atlantic City
# 4                                        NaN   Atlantic City
# 5                                        NaN   Atlantic City
# 6                                        NaN   Atlantic City
# 7                                        NaN        Barnegat
# 8                                        NaN   Basking Ridge
# 9                                        NaN         Bayonne
# 10                     Village at Bedminster      Bedminster
# 11                                       NaN         Bellmar
# 12                                       NaN          Bergen
# 13                                       NaN   Bernardsville
# 14                                       NaN       Blackwood
# 15                                       NaN         Boonton
# 16                ACME Commons at Bordentown      Bordentown
# 17                     Shoppes at Branchburg      Branchburg
# 18                                       NaN      Branchburg
# 19                                       NaN           Brick
# 20                       Bridgewater Commons     Bridgewater
# 21                                       NaN     Bridgewater
# 22        The Village at Bridgewater Commons     Bridgewater
# 23                                       NaN      Burlington
# 24                                       NaN          Camden
# 25                                       NaN    Cedar Knolls
# 26                                       NaN         Chatham
# 27                  Short Hills Towne Centre     Cherry Hill
# 28                                       NaN     Cherry Hill
# 29                                       NaN     Cherry Hill
# ..                                       ...             ...
# 217                        Ocean County Mall      Toms River
# 218                                      NaN      Toms River
# 219                                      NaN      Toms River
# 220                                      NaN         Trenton
# 221                                      NaN    Turnersville
# 222                                      NaN    Turnersville
# 223                                      NaN           Union
# 224                                      NaN           Union
# 225                                      NaN           Union
# 226                                      NaN          Vernon
# 227                          Cumberland Mall        Vineland
# 228               Cedar Hill Shopping Center        Voorhees
# 229                                      NaN          Warren
# 230                                      NaN        Watchung
# 231                                      NaN           Wayne
# 232                         Willowbrook Mall           Wayne
# 233                                      NaN           Wayne
# 234                                      NaN           Wayne
# 235                                      NaN           Wayne
# 236                         Willowbrook Mall           Wayne
# 237                                      NaN   West Caldwell
# 238                                      NaN   West New York
# 239                                      NaN       Westfield
# 240                          Meisel Building        Westwood
# 241                                      NaN      Woodbridge
# 242                                      NaN      Woodbridge
# 243                        Woodbridge Center      Woodbridge
# 244                                      NaN  Woodcliff Lake
# 245                                      NaN         Wyckoff
# 246                                      NaN       Yardville
#
#     CountrySubdivisionCode    Income  Population Latitude Longitude  \
# 0                       NJ   63887.0      8370.0  39.4622  -74.4947
# 1                       NJ  151875.0      6820.0   41.029  -74.1281
# 2                       NJ   39324.0     15830.0  40.2313  -74.0451
# 3                       NJ   26006.0     39075.0  39.3608   -74.437
# 4                       NJ   26006.0     39075.0  39.3785  -74.4291
# 5                       NJ   26006.0     39075.0  39.3524  -74.4446
# 6                       NJ   26006.0     39075.0    39.36  -74.4212
# 7                       NJ   69877.0     22141.0  39.7596  -74.2465
# 8                       NJ       NaN         NaN  40.6524  -74.5766
# 9                       NJ   56701.0     66719.0  40.6678  -74.1042
# 10                      NJ  104452.0      8244.0  40.6501  -74.6416
# 11                      NJ       NaN         NaN  40.1982  -74.0991
# 12                      NJ       NaN         NaN  40.9569  -74.0692
# 13                      NJ  150635.0      7792.0  40.7204  -74.5637
# 14                      NJ       NaN         NaN  39.7849  -75.0528
# 15                      NJ   91055.0      8390.0  40.9087   -74.397
# 16                      NJ   85640.0     11808.0  40.1327   -74.724
# 17                      NJ  129237.0     14683.0  40.6054  -74.6891
# 18                      NJ  129237.0     14683.0
# 19                      NJ   73051.0     75118.0  40.0579  -74.1519
# 20                      NJ  122684.0     45336.0  40.5864  -74.6199
# 21                      NJ  122684.0     45336.0  40.5628  -74.5527
# 22                      NJ  122684.0     45336.0   40.583  -74.6149
# 23                      NJ   50709.0      9835.0  40.0351  -74.8223
# 24                      NJ   26105.0     75550.0  39.9487  -75.1226
# 25                      NJ       NaN         NaN  40.8134  -74.4696
# 26                      NJ  176364.0     10507.0  40.7465  -74.4307
# 27                      NJ   97069.0     71204.0  39.8636  -74.9652
# 28                      NJ   97069.0     71204.0  39.9368  -75.0449
# 29                      NJ   97069.0     71204.0  39.9334  -75.0306
# ..                     ...       ...         ...      ...       ...
# 217                     NJ   76051.0     91415.0  39.9804  -74.1792
# 218                     NJ   76051.0     91415.0  39.9582  -74.1721
# 219                     NJ   76051.0     91415.0  40.0448  -74.2241
# 220                     NJ   35524.0     84867.0   40.178  -74.6312
# 221                     NJ       NaN         NaN   39.755  -75.0466
# 222                     NJ       NaN         NaN  39.7327  -75.0398
# 223                     NJ   79324.0     58499.0  40.6765  -74.2285
# 224                     NJ   79324.0     58499.0  40.6888  -74.3072
# 225                     NJ   79324.0     58499.0  40.7171  -74.2855
# 226                     NJ   90805.0     22572.0  41.1949  -74.4831
# 227                     NJ   51113.0     60824.0  39.4319   -75.038
# 228                     NJ   85199.0     29386.0   39.835  -74.9252
# 229                     NJ  154647.0     15998.0  40.6163  -74.4944
# 230                     NJ  121678.0      5961.0  40.6404  -74.4225
# 231                     NJ  108092.0     55154.0  40.9607  -74.2402
# 232                     NJ  108092.0     55154.0  40.8875   -74.255
# 233                     NJ  108092.0     55154.0  40.9447   -74.205
# 234                     NJ  108092.0     55154.0  40.9391   -74.269
# 235                     NJ  108092.0     55154.0  40.8899  -74.2503
# 236                     NJ  108092.0     55154.0  40.8887  -74.2594
# 237                     NJ  105931.0     10932.0  40.8489  -74.2969
# 238                     NJ   50477.0     53345.0   40.783  -74.0072
# 239                     NJ  159923.0     30591.0  40.6521  -74.3469
# 240                     NJ   95685.0     11246.0  40.9921  -74.0317
# 241                     NJ   83266.0    101639.0   40.557  -74.2632
# 242                     NJ   83266.0    101639.0    40.56  -74.2646
# 243                     NJ   83266.0    101639.0  40.5559  -74.3015
# 244                     NJ  161250.0      5868.0  41.0431   -74.071
# 245                     NJ  147463.0     17231.0  41.0116  -74.1678
# 246                     NJ       NaN         NaN  40.1764  -74.6317
#
#                                      target search add
# 0                        405 S. Pitney Road,Absecon,NJ
# 1                        45 Demercurio Dr,Allendale,NJ
# 2                   2331 State Route 66,Asbury Park,NJ
# 3           120 North Michigan Avenue,Atlantic City,NJ
# 4                       1 Castle Blvd,Atlantic City,NJ
# 5                      2831 Boardwalk,Atlantic City,NJ
# 6      1000 Boardwalk at Virginia Ave,Atlantic City,NJ
# 7                            912 W Bay Ave,Barnegat,NJ
# 8               655 Martinsville Road,Basking Ridge,NJ
# 9                             1 Lefante Way,Bayonne,NJ
# 10                432 US Highway 202/206,Bedminster,NJ
# 11       Garden State Pkwy, Mile Marker 100,Bellmar,NJ
# 12                          700 Paramus Park,Bergen,NJ
# 13                  80 Morristown Rd.,Bernardsville,NJ
# 14                1125 S Black Horse Pike,Blackwood,NJ
# 15                        550 Myrtle Avenue,Boonton,NJ
# 16                   282 Dunns Mill Road,Bordentown,NJ
# 17      240 Raritan Valley College Drive,Branchburg,NJ
# 18                  531 Route 22 East #8,Branchburg,NJ
# 19                           570 Rte. 70 West,Brick,NJ
# 20                      400 Commons Way,Bridgewater,NJ
# 21                   200 Promenade Blvd,Bridgewater,NJ
# 22                 610 Commons Way 4300,Bridgewater,NJ
# 23                        2703 Route 541,Burlington,NJ
# 24                               326 Penn St,Camden,NJ
# 25                  178 Hanover Avenue,Cedar Knolls,NJ
# 26                         640 Shunpike Rd.,Chatham,NJ
# 27                     480 Evesham Road,Cherry Hill,NJ
# 28                            600 Rt 38,Cherry Hill,NJ
# 29                 512 Haddonfield Road,Cherry Hill,NJ
# ..                                                 ...
# 217                      1201 HOOPER AVE,Toms River,NJ
# 218                    353 Route 37 East,Toms River,NJ
# 219                     2360 Lakewood Rd,Toms River,NJ
# 220                      200 Uncle Petes Rd,Trenton,NJ
# 221                      5340 Route 42,Turnersville,NJ
# 222              4001 Black Horse Pike,Turnersville,NJ
# 223                           1000 Morris Ave,Union,NJ
# 224                        2698 Route 22 East,Union,NJ
# 225                      2235 Springfield Ave,Union,NJ
# 226                               530 CR-515,Vernon,NJ
# 227                    3849 S. Delsea Road,Vineland,NJ
# 228                           148 Route 73,Voorhees,NJ
# 229                        4 Mount Bethel Rd,Warren,NJ
# 230                     1515 US Highway 22,Watchung,NJ
# 231                     1118 Hamburg Turnpike,Wayne,NJ
# 232                     1100 Willowbrook Blvd,Wayne,NJ
# 233                      183 Hamburg Turnpike,Wayne,NJ
# 234                       1606 Route 23 North,Wayne,NJ
# 235                         57 state route 23,Wayne,NJ
# 236                     1400 Willowbrook Mall,Wayne,NJ
# 237                  546 Passaic Ave.,West Caldwell,NJ
# 238              55-1 Riverwalk Place,West New York,NJ
# 239                    117 Central Avenue,Westfield,NJ
# 240                    102 Westwood Avenue,Westwood,NJ
# 241                     Mile Marker 92.9,Woodbridge,NJ
# 242  New Jersey Turnpike, Mile Post 92.9 S,Woodbrid...
# 243          250 Woodbridge Center Drive,Woodbridge,NJ
# 244            520 Chestnut Ridge Rd,Woodcliff Lake,NJ
# 245                     325 Franklin Avenue,Wyckoff,NJ
# 246     Mile post 57.8-North, NJ Turnpike,Yardville,NJ
#
# [247 rows x 11 columns]

# %%
starbucks_df =starbucks_df.drop(columns=['Latitude', 'Longitude'])
starbucks_df = 
starbucks_df.head()
# Out:
#                           Name                    Street1 Street2  \
# 0                     Galloway         405 S. Pitney Road     NaN
# 1       Acme - Allendale #1095           45 Demercurio Dr     NaN
# 2          Target Ocean T-1378        2331 State Route 66     NaN
# 3      Atlantic City, The Walk  120 North Michigan Avenue     NaN
# 4  Golden Nugget-Atlantic City              1 Castle Blvd     NaN
#
#                                    Street3           City  \
# 0  Galloway Village Square Shopping Center        Absecon
# 1                                      NaN      Allendale
# 2                                      NaN    Asbury Park
# 3                                      NaN  Atlantic City
# 4                                      NaN  Atlantic City
#
#   CountrySubdivisionCode    Income  Population  lat-API long-API  \
# 0                     NJ   63887.0      8370.0  39.4622 -74.4947
# 1                     NJ  151875.0      6820.0   41.029 -74.1281
# 2                     NJ   39324.0     15830.0  40.2313 -74.0451
# 3                     NJ   26006.0     39075.0  39.3608  -74.437
# 4                     NJ   26006.0     39075.0  39.3785 -74.4291
#
#                             target search add
# 0               405 S. Pitney Road,Absecon,NJ
# 1               45 Demercurio Dr,Allendale,NJ
# 2          2331 State Route 66,Asbury Park,NJ
# 3  120 North Michigan Avenue,Atlantic City,NJ
# 4              1 Castle Blvd,Atlantic City,NJ

# %%
starbucks_df = starbucks_df.rename(columns={"lat-API":"Latitude","long-API":"Longitude"})
starbucks_df.head()
# Out:
#                           Name                    Street1 Street2  \
# 0                     Galloway         405 S. Pitney Road     NaN
# 1       Acme - Allendale #1095           45 Demercurio Dr     NaN
# 2          Target Ocean T-1378        2331 State Route 66     NaN
# 3      Atlantic City, The Walk  120 North Michigan Avenue     NaN
# 4  Golden Nugget-Atlantic City              1 Castle Blvd     NaN
#
#                                    Street3           City  \
# 0  Galloway Village Square Shopping Center        Absecon
# 1                                      NaN      Allendale
# 2                                      NaN    Asbury Park
# 3                                      NaN  Atlantic City
# 4                                      NaN  Atlantic City
#
#   CountrySubdivisionCode    Income  Population Latitude Longitude  \
# 0                     NJ   63887.0      8370.0  39.4622  -74.4947
# 1                     NJ  151875.0      6820.0   41.029  -74.1281
# 2                     NJ   39324.0     15830.0  40.2313  -74.0451
# 3                     NJ   26006.0     39075.0  39.3608   -74.437
# 4                     NJ   26006.0     39075.0  39.3785  -74.4291
#
#                             target search add
# 0               405 S. Pitney Road,Absecon,NJ
# 1               45 Demercurio Dr,Allendale,NJ
# 2          2331 State Route 66,Asbury Park,NJ
# 3  120 North Michigan Avenue,Atlantic City,NJ
# 4              1 Castle Blvd,Atlantic City,NJ

# %%
analysis_df = pd.DataFrame(starbucks_df['City'].value_counts())
analysis_df['Median Income'] = ""
analysis_df['Population'] = ""



analysis_df
# Out:
#                 City Median Income Population
# Cherry Hill        8
# Wayne              6
# Edison             5
# Fort Lee           5
# Paramus            5
# Jersey City        5
# Freehold           4
# Atlantic City      4
# Newark             4
# Mount Laurel       4
# Lawrenceville      4
# Phillipsburg       3
# Rockaway           3
# Union              3
# Hoboken            3
# Toms River         3
# Woodbridge         3
# Cranbury           3
# Bridgewater        3
# Piscataway         3
# Moorestown         2
# Cranford           2
# South Amboy        2
# Ridgewood          2
# Edgewater          2
# Denville           2
# New Brunswick      2
# Hackettstown       2
# Sewell             2
# Morristown         2
# ...              ...           ...        ...
# Mahwah             1
# Forked River       1
# Elizabeth          1
# Glen Ridge         1
# Westfield          1
# Old Bridge         1
# Midland Park       1
# Matawan            1
# Riverside          1
# Millburn           1
# Boonton            1
# Bayonne            1
# West Caldwell      1
# Absecon            1
# Gillette           1
# Warren             1
# Oakhurst           1
# Pennington         1
# Brick              1
# Florham Park       1
# Linden             1
# Woodcliff Lake     1
# South Orange       1
# Hamilton           1
# Somerville         1
# Medford            1
# Bernardsville      1
# Hillsborough       1
# Ocean City         1
# Morris Plains      1
#
# [163 rows x 3 columns]

# %%
# Out:
# C:\Users\Kabooboo\Anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Index'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-a0efab559760> in <module>
#       1 df_concat = pd.concat([analysis_df, starbucks_df]).reset_index().drop_duplicates(['City'])
# ----> 2 df_concat.set_index('Index', inplace=True)
#       3 df_concat[df_concat.index.isin(starbucks_df.index)]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    3907                 names.append(None)
#    3908             else:
# -> 3909                 level = frame[col]._values
#    3910                 names.append(col)
#    3911                 if drop:
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~\Anaconda3\envs\PythonData\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Index'
