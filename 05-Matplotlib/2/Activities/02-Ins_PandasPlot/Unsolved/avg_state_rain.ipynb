# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
#Load in csv

rain_df =pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
#Set x axis and tick locations

x_axis = np.arange(len(rain_df))
tick_locations = [value for value in x_axis]

# %%
#Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="center")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x2311302c630>,
#   <matplotlib.axis.XTick at 0x23113010e80>,
#   <matplotlib.axis.XTick at 0x23113010b00>,
#   <matplotlib.axis.XTick at 0x231130c2ac8>,
#   <matplotlib.axis.XTick at 0x231130c2f60>,
#   <matplotlib.axis.XTick at 0x231130d3470>,
#   <matplotlib.axis.XTick at 0x231130c28d0>,
#   <matplotlib.axis.XTick at 0x231130d3a90>,
#   <matplotlib.axis.XTick at 0x231130d3e80>,
#   <matplotlib.axis.XTick at 0x231130d94e0>,
#   <matplotlib.axis.XTick at 0x231130d99e8>,
#   <matplotlib.axis.XTick at 0x231130d9ef0>,
#   <matplotlib.axis.XTick at 0x231130e1438>,
#   <matplotlib.axis.XTick at 0x231130e1940>,
#   <matplotlib.axis.XTick at 0x231130e1e48>,
#   <matplotlib.axis.XTick at 0x231130e1f28>,
#   <matplotlib.axis.XTick at 0x231130d9588>,
#   <matplotlib.axis.XTick at 0x231130e9048>,
#   <matplotlib.axis.XTick at 0x231130e9748>,
#   <matplotlib.axis.XTick at 0x231130e9c50>,
#   <matplotlib.axis.XTick at 0x231130f3198>,
#   <matplotlib.axis.XTick at 0x231130f36a0>,
#   <matplotlib.axis.XTick at 0x231130f3ba8>,
#   <matplotlib.axis.XTick at 0x231130fa160>,
#   <matplotlib.axis.XTick at 0x231130f35f8>,
#   <matplotlib.axis.XTick at 0x231130e9a58>,
#   <matplotlib.axis.XTick at 0x231130fa4e0>,
#   <matplotlib.axis.XTick at 0x231130faa20>,
#   <matplotlib.axis.XTick at 0x231130faf28>,
#   <matplotlib.axis.XTick at 0x23113103470>,
#   <matplotlib.axis.XTick at 0x23113103978>,
#   <matplotlib.axis.XTick at 0x23113103e80>,
#   <matplotlib.axis.XTick at 0x2311310a3c8>,
#   <matplotlib.axis.XTick at 0x23113103940>,
#   <matplotlib.axis.XTick at 0x231130faef0>,
#   <matplotlib.axis.XTick at 0x231130e9c18>,
#   <matplotlib.axis.XTick at 0x2311310a470>,
#   <matplotlib.axis.XTick at 0x2311310ac88>,
#   <matplotlib.axis.XTick at 0x23113114518>,
#   <matplotlib.axis.XTick at 0x23113114a20>,
#   <matplotlib.axis.XTick at 0x23113114f28>,
#   <matplotlib.axis.XTick at 0x2311311a470>,
#   <matplotlib.axis.XTick at 0x2311311a978>,
#   <matplotlib.axis.XTick at 0x231131149e8>,
#   <matplotlib.axis.XTick at 0x231130fa550>,
#   <matplotlib.axis.XTick at 0x2311311acc0>,
#   <matplotlib.axis.XTick at 0x23113124208>,
#   <matplotlib.axis.XTick at 0x23113124710>,
#   <matplotlib.axis.XTick at 0x23113124c18>,
#   <matplotlib.axis.XTick at 0x2311312d198>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.75, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(325.45833333333337, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()

# %% [markdown]
# Using Pandas to Chart a DataFrame

# %%
#Filter the DataFrame down only to those columns to chart 
state_and_inches = rain_df[["State","Inches"]]

#Set the index to be "State" so they will be used as columns
state_and_inches = state_and_inches.set_index("State")

state_and_inches.head()
# Out:
#             Inches
# State
# Alabama       58.3
# Alaska        22.5
# Arizona       13.6
# Arkansas      50.6
# California    22.2

# %%
#Use Dataframe.plot() in order to create a bar chart for the data
state_and_inches.plot(kind ="bar",figsize =(20,3))

#Set a title for the chart
plt.title ("Average Rain Per State")

plt.show()
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="2000">
