# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np

# Google developer API key
from config import gkey

# %%
locations_df = pd.read_csv("../Resources/starbucks.csv")
locations_df
# Out:
#                                        Id  StarbucksId  \
# 0    1d14dd7c-1afb-452b-9322-59ec5b4460af        13780
# 1    7132a578-140e-4fdf-b1a5-825f5cafb7d1         6820
# 2    f2c4ceef-134b-4d56-8cf4-08e1d25dd4e3        13023
# 3    3830478f-f10f-4c0d-b5b6-571f4d004398         9365
# 4    6f1c23f0-70d7-49a4-b7d2-6926623783ee        19096
# 5    87744b14-6b18-48f1-8f1c-6c1161289b90        18167
# 6    329f304f-3222-4354-85e1-da527976647f        88966
# 7    3f1f7dff-0631-43c9-a575-7373a1dd5020      1015682
# 8    c83cd765-3db7-4717-b70f-295977c0abb3        11233
# 9    ae0d542c-4de3-4737-a5b5-0c9737c04999         7489
# 10   2e07c347-134b-47b1-bd2f-f60ea38926dd        18054
# 11   46fd42a8-c0fe-48bf-a438-d9e210cc1f5a      1009334
# 12   66f67e3e-a7c6-4b5c-987e-0447709b2b53      1006278
# 13   94e60425-a09f-496f-a339-71343a8a8ec9        18360
# 14   a5dcea82-5b76-4ab5-956e-93bf9f4ec4e6      1016493
# 15   4852dcb0-1905-41f5-95b4-822572d63d8d        17431
# ...

# %%
locations_df.drop(['Id', 'BrandName','OwnershipType','CountryCode','TimezoneOffset','TimezoneId','TimezoneOlsonId'], axis=1, inplace=True)
locations_df
# Out:
#      StarbucksId                                 Name   StoreNumber  \
# 0          13780                             Galloway    8838-94558
# 1           6820               Acme - Allendale #1095   73856-93632
# 2          13023                Tropicana Marketplace   75621-82681
# 3           9365              Atlantic City, The Walk    7849-80862
# 4          19096  Tropicana Casino & Resort-The Quart  14932-150984
# 5          18167   Trump Taj Mahal-Atlantic City-Main  75451-102575
# 6          88966          Golden Nugget-Atlantic City  17549-173804
# 7        1015682                Acme - Barnegat #7921  47680-258706
# 8          11233                   Bernards-Riverwalk    7669-32160
# 9           7489           Stop & Shop - Bayonne #853  73780-111885
# 10         18054                Village at Bedminster  13295-104959
# 11       1009334             NJ Monmouth Travel Plaza  23709-231486
# 12       1006278       Paramus Park Mall Center Court  21770-213785
# ...

# %%
locations_df['City'].unique()
# Out:
# array(['Absecon', 'Allendale', 'Atlantic City', 'Barnegat',
#        'Basking  Ridge', 'Bayonne', 'Bedminster', 'Bellmar', 'Bergen',
#        'Bernardsville', 'Boonton', 'Bordentown', 'Branchburg', 'Brick',
#        'Bridgewater', 'Burlington', 'Camden', 'Cedar Knolls', 'Chatham',
#        'Cherry Hill', 'Chester', 'Clark', 'Clementon', 'Clifton',
#        'Closter', 'CLOSTER', 'Cranbury', 'Cranford', 'Delran', 'Denville',
#        'Deptford', 'East Brunswick', 'East Hanover', 'East Ridgefield',
#        'East Rutherford', 'Eatontown', 'Edgewater', 'Edison', 'Elizabeth',
#        'Englewood', 'Evesham', 'Fairfield', 'Fairlawn', 'Flemington',
#        'Florham Park', 'Forked River', 'Fort Lee', 'Franklin',
#        'Franklin Lakes', 'Franklin TWP', 'Freehold', 'Galloway',
#        'Gillette', 'Glen Ridge', 'Glen Rock', 'Gloucester Township',
#        'Green Brook', 'Hackensack', 'Hackettstown', 'Haddonfield',
#        'Hamilton', 'Hammonton', 'Hasbrouck Heights', 'Hillsborough',
# ...

# %%
locations_df['City'].value_counts()
# Out:
# Cherry Hill        8
# Paramus            6
# Wayne              6
# Edison             5
# Atlantic City      5
# Fort Lee           5
# Jersey City        5
# Newark             4
# Lawrenceville      4
# Mount Laurel       4
# Freehold           4
# Toms River         3
# Hoboken            3
# Union              3
# Phillipsburg       3
# Cranbury           3
# Rockaway           3
# Bridgewater        3
# Piscataway         3
# East Rutherford    2
# Hackettstown       2
# Sicklerville       2
# North Bergen       2
# New Brunswick      2
# North Brunswick    2
# Cranford           2
# Morristown         2
# Princeton          2
# Edgewater          2
# Turnersville       2
#                   ..
# Milltown           1
# South Orange       1
# Glen Rock          1
# CLOSTER            1
# Closter            1
# Absecon            1
# Old Bridge         1
# Chatham            1
# Yardville          1
# Somerset           1
# Delran             1
# New Providence     1
# ...
