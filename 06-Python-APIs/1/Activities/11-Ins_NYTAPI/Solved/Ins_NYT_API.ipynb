# %%
# Dependencies
import requests
from pprint import pprint
from config import api_key

url = "https://api.nytimes.com/svc/search/v2/articlesearch.json?"

# %%
# Search for articles that mention granola
query = "granola"

# %%
# Build query URL
query_url = url + "api-key=" + 'ZGNdrDGLKX3zPfsqXbONlN9HntYqXKuH' + "&q=" + query
query_url
# Out:
# 'https://api.nytimes.com/svc/search/v2/articlesearch.json?api-key=ZGNdrDGLKX3zPfsqXbONlN9HntYqXKuH&q=granola'

# %%
# Request articles
articles = requests.get(query_url).json()
print(articles)
# The "response" property in articles contains the actual articles
# list comprehension.
articles_list = [article for article in articles["response"]["docs"]]
pprint(articles_list)
# Out:
# {'status': 'OK', 'copyright': 'Copyright (c) 2019 The New York Times Company. All Rights Reserved.', 'response': {'docs': [{'web_url': 'https://cooking.nytimes.com/recipes/1019514-granola-bites', 'snippet': 'These chewy-crunchy, salty-sweet breakfast balls are great for eating on the go because they don’t crumble and leave a mess. They take minutes to blend and a few more to roll, but if you make them a friends-and-family cooking project, the process ...', 'lead_paragraph': "These chewy-crunchy, salty-sweet breakfast balls are great for eating on the go because they don’t crumble and leave a mess. They take minutes to blend and a few more to roll, but if you make them a friends-and-family cooking project, the process can go even faster. Feel free to experiment here. You can swap out the almonds for cashews, the cherries for other dried fruits, and the sunflower seeds for shelled pumpkin seeds. Just keep the dates and make sure they're Medjool, which are softer and more thin-skinned than other varieties. The dates are the glue that hold the other ingredients together.", 'blog': {}, 'source': 'du_recipe', 'multimedia': [{'rank': 1, 'subtype': 'thumbnail', 'caption': "Genevieve Ko's granola balls.", 'credit': 'David Malosh for The New York Times', 'type': 'image', 'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-thumbStandard.jpg', 'height': 75, 'width': 75, 'legacy': {}, 'subType': 'thumbnail', 'crop_name': 'thumbStandard'}, {'rank': 1, 'subtype': 'large', 'caption': "Genevieve Ko's granola balls.", 'credit': 'David Malosh for The New York Times', 'type': 'image', 'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-articleLarge.jpg', 'height': 382, 'width': 600, 'legacy': {}, 'subType': 'large', 'crop_name': 'articleLarge'}], 'headline': {'main': '', 'kicker': None, 'content_kicker': None, 'print_headline': None, 'name': 'Granola Bites', 'seo': None, 'sub': None}, 'keywords': [], 'pub_date': '2018-08-24T04:00:00+0000', 'document_type': 'recipe', 'byline': {'original': 'Genevieve Ko', 'person': [{'firstname': 'Genevieve', 'middlename': None, 'lastname': 'Ko', 'qualifier': None, 'title': None, 'role': 'reported', 'organization': '', 'rank': 1}], 'organization': None}, 'type_of_material': 'Recipe', '_id': '5b89618e9fb2bb0001ad099f', 'word_count': 124, 'score': 0.0}, {'web_url': 'https://www.nytimes.com/2018/02/14/books/review/hippie-food-jonathan-kauffman.html', 'snippet': 'In “Hippie Food,” Jonathan Kauffman tracks the emergence of the organic, politicized diet so many Americans love today.', 'lead_paragraph': 'In “Hippie Food,” Jonathan Kauffman tracks the emergence of the organic, politicized diet so many Americans love today.', 'print_page': '11', 'blog': {}, 'source': 'The New York Times', 'multimedia': [{'rank': 0, 'subtype': 'xlarge', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-articleLarge.jpg', 'height': 444, 'width': 600, 'legacy': {'xlarge': 'images/2018/02/18/books/review/18Pollan/18Pollan-articleLarge.jpg', 'xlargewidth': 600, 'xlargeheight': 444}, 'subType': 'xlarge', 'crop_name': 'articleLarge'}, {'rank': 0, 'subtype': 'wide', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-thumbWide.jpg', 'height': 126, 'width': 190, 'legacy': {'wide': 'images/2018/02/18/books/review/18Pollan/18Pollan-thumbWide.jpg', 'widewidth': 190, 'wideheight': 126}, 'subType': 'wide', 'crop_name': 'thumbWide'}, {'rank': 0, 'subtype': 'thumbnail', 'caption': None, 'credit': None, 'type': 'image', 'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-thumbStandard.jpg', 'height': 75, 'width': 75, 'legacy': {'thumbnail': 'images/2018/02/18/books/review/18Pollan/18Pollan-thumbStandard.jpg', 'thumbnailwidth': 75, 'thumbnailheight': 75}, 'subType': 'thumbnail', 'crop_name': 'thumbStandard'}, {'rank': 0, 'subtype': 'articleInline', 'caption': None, 'cre ...
# [{'_id': '5b89618e9fb2bb0001ad099f',
#   'blog': {},
#   'byline': {'organization': None,
#              'original': 'Genevieve Ko',
#              'person': [{'firstname': 'Genevieve',
#                          'lastname': 'Ko',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'recipe',
#   'headline': {'content_kicker': None,
#                'kicker': None,
#                'main': '',
#                'name': 'Granola Bites',
#                'print_headline': None,
#                'seo': None,
#                'sub': None},
#   'keywords': [],
#   'lead_paragraph': 'These chewy-crunchy, salty-sweet breakfast balls are '
#                     'great for eating on the go because they don’t crumble and '
#                     'leave a mess. They take minutes to blend and a few more '
#                     'to roll, but if you make them a friends-and-family '
#                     'cooking project, the process can go even faster. Feel '
#                     'free to experiment here. You can swap out the almonds for '
#                     'cashews, the cherries for other dried fruits, and the '
#                     'sunflower seeds for shelled pumpkin seeds. Just keep the '
#                     "dates and make sure they're Medjool, which are softer and "
#                     'more thin-skinned than other varieties. The dates are the '
#                     'glue that hold the other ingredients together.',
#   'multimedia': [{'caption': "Genevieve Ko's granola balls.",
#                   'credit': 'David Malosh for The New York Times',
#                   'crop_name': 'thumbStandard',
#                   'height': 75,
#                   'legacy': {},
#                   'rank': 1,
#                   'subType': 'thumbnail',
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-thumbStandard.jpg',
#                   'width': 75},
#                  {'caption': "Genevieve Ko's granola balls.",
#                   'credit': 'David Malosh for The New York Times',
#                   'crop_name': 'articleLarge',
#                   'height': 382,
#                   'legacy': {},
#                   'rank': 1,
#                   'subType': 'large',
#                   'subtype': 'large',
#                   'type': 'image',
#                   'url': 'images/2018/08/29/dining/ko-granola-balls-horizontal/ko-granola-balls-horizontal-articleLarge.jpg',
#                   'width': 600}],
#   'pub_date': '2018-08-24T04:00:00+0000',
#   'score': 0.0,
#   'snippet': 'These chewy-crunchy, salty-sweet breakfast balls are great for '
#              'eating on the go because they don’t crumble and leave a mess. '
#              'They take minutes to blend and a few more to roll, but if you '
#              'make them a friends-and-family cooking project, the process ...',
#   'source': 'du_recipe',
#   'type_of_material': 'Recipe',
#   'web_url': 'https://cooking.nytimes.com/recipes/1019514-granola-bites',
#   'word_count': 124},
#  {'_id': '5a8408c5410cf7000162bd70',
#   'blog': {},
#   'byline': {'organization': None,
#              'original': 'By MICHAEL POLLAN',
#              'person': [{'firstname': 'Michael',
#                          'lastname': 'POLLAN',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': 'Nonfiction',
#                'kicker': 'Nonfiction',
#                'main': 'How We Got From Twinkies to Tofu',
#                'name': None,
#                'print_headline': 'Granola',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Books and Literature'},
#                {'major': 'N',
#                 'name': 'creative_works',
#                 'rank': 2,
#                 'value': 'Hippie Food: How Back-to-the-Landers, Longhairs, and '
#                          'Revolutionaries Changed the Way We Eat (Book)'},
#                {'major': 'N',
#                 'name': 'persons',
#                 'rank': 3,
#                 'value': 'Kauffman, Jonathan (1971- )'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 4,
#                 'value': 'Organic Foods and Products'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 5,
#                 'value': 'Hippies'}],
#   'lead_paragraph': 'In “Hippie Food,” Jonathan Kauffman tracks the emergence '
#                     'of the organic, politicized diet so many Americans love '
#                     'today.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleLarge',
#                   'height': 444,
#                   'legacy': {'xlarge': 'images/2018/02/18/books/review/18Pollan/18Pollan-articleLarge.jpg',
#                              'xlargeheight': 444,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-articleLarge.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbWide',
#                   'height': 126,
#                   'legacy': {'wide': 'images/2018/02/18/books/review/18Pollan/18Pollan-thumbWide.jpg',
#                              'wideheight': 126,
#                              'widewidth': 190},
#                   'rank': 0,
#                   'subType': 'wide',
#                   'subtype': 'wide',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-thumbWide.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbStandard',
#                   'height': 75,
#                   'legacy': {'thumbnail': 'images/2018/02/18/books/review/18Pollan/18Pollan-thumbStandard.jpg',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subType': 'thumbnail',
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-thumbStandard.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleInline',
#                   'height': 141,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'articleInline',
#                   'subtype': 'articleInline',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-articleInline.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog225',
#                   'height': 167,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog225',
#                   'subtype': 'blog225',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-blog225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 316,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-blog427.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog480',
#                   'height': 355,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog480',
#                   'subtype': 'blog480',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-blog480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 395,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-blog533.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallInline',
#                   'height': 112,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallInline',
#                   'subtype': 'blogSmallInline',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-blogSmallInline.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallThumb',
#                   'subtype': 'blogSmallThumb',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-blogSmallThumb.jpg',
#                   'width': 50},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'facebookJumbo',
#                   'height': 550,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'facebookJumbo',
#                   'subtype': 'facebookJumbo',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-facebookJumbo.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'filmstrip',
#                   'height': 190,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'filmstrip',
#                   'subtype': 'filmstrip',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-filmstrip.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpLarge',
#                   'height': 287,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpLarge',
#                   'subtype': 'hpLarge',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-hpLarge.jpg',
#                   'width': 511},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'hpSmall',
#                   'height': 121,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'hpSmall',
#                   'subtype': 'hpSmall',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-hpSmall.jpg',
#                   'width': 163},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'jumbo',
#                   'height': 758,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'jumbo',
#                   'subtype': 'jumbo',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-jumbo.jpg',
#                   'width': 1024},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontal375',
#                   'height': 250,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontal375',
#                   'subtype': 'largeHorizontal375',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-largeHorizontal375.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeHorizontalJumbo',
#                   'height': 683,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeHorizontalJumbo',
#                   'subtype': 'largeHorizontalJumbo',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-largeHorizontalJumbo.jpg',
#                   'width': 1024},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen573',
#                   'height': 322,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen573',
#                   'subtype': 'largeWidescreen573',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-largeWidescreen573.jpg',
#                   'width': 573},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'largeWidescreen1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'largeWidescreen1050',
#                   'subtype': 'largeWidescreen1050',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-largeWidescreen1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master1050',
#                   'height': 777,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master1050',
#                   'subtype': 'master1050',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-master1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master180',
#                   'height': 133,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master180',
#                   'subtype': 'master180',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-master180.jpg',
#                   'width': 180},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master315',
#                   'height': 233,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master315',
#                   'subtype': 'master315',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-master315.jpg',
#                   'width': 315},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master495',
#                   'height': 367,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master495',
#                   'subtype': 'master495',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-master495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master768',
#                   'height': 569,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master768',
#                   'subtype': 'master768',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-master768.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'master675',
#                   'height': 500,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'master675',
#                   'subtype': 'master675',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-master675.jpg',
#                   'width': 675},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumFlexible177',
#                   'height': 131,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumFlexible177',
#                   'subtype': 'mediumFlexible177',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-mediumFlexible177.jpg',
#                   'width': 177},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumSquare149',
#                   'height': 149,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumSquare149',
#                   'subtype': 'mediumSquare149',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-mediumSquare149.jpg',
#                   'width': 149},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo210',
#                   'height': 140,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo210',
#                   'subtype': 'mediumThreeByTwo210',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-mediumThreeByTwo210.jpg',
#                   'width': 210},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo225',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo225',
#                   'subtype': 'mediumThreeByTwo225',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-mediumThreeByTwo225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo440',
#                   'height': 293,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo440',
#                   'subtype': 'mediumThreeByTwo440',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-mediumThreeByTwo440.jpg',
#                   'width': 440},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo378',
#                   'height': 252,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo378',
#                   'subtype': 'mediumThreeByTwo378',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-mediumThreeByTwo378.jpg',
#                   'width': 378},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'mediumThreeByTwo252',
#                   'height': 168,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'mediumThreeByTwo252',
#                   'subtype': 'mediumThreeByTwo252',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-mediumThreeByTwo252.jpg',
#                   'width': 252},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'miniMoth',
#                   'height': 70,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'miniMoth',
#                   'subtype': 'miniMoth',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-miniMoth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'moth',
#                   'height': 151,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'moth',
#                   'subtype': 'moth',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-moth.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'popup',
#                   'height': 481,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'popup',
#                   'subtype': 'popup',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-popup.jpg',
#                   'width': 650},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'sfSpan',
#                   'height': 263,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'sfSpan',
#                   'subtype': 'sfSpan',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-sfSpan.jpg',
#                   'width': 395},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'slide',
#                   'height': 444,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'slide',
#                   'subtype': 'slide',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-slide.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'smallSquare168',
#                   'height': 168,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'smallSquare168',
#                   'subtype': 'smallSquare168',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-smallSquare168.jpg',
#                   'width': 168},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'smallSquare252',
#                   'height': 252,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'smallSquare252',
#                   'subtype': 'smallSquare252',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-smallSquare252.jpg',
#                   'width': 252},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'square320',
#                   'height': 320,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'square320',
#                   'subtype': 'square320',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-square320.jpg',
#                   'width': 320},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'square640',
#                   'height': 640,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'square640',
#                   'subtype': 'square640',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-square640.jpg',
#                   'width': 640},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'superJumbo',
#                   'height': 1044,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'superJumbo',
#                   'subtype': 'superJumbo',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-superJumbo.jpg',
#                   'width': 1410},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbLarge',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'thumbLarge',
#                   'subtype': 'thumbLarge',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-thumbLarge.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagArticle',
#                   'height': 438,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagArticle',
#                   'subtype': 'tmagArticle',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-tmagArticle.jpg',
#                   'width': 592},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'tmagSF',
#                   'height': 268,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'tmagSF',
#                   'subtype': 'tmagSF',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-tmagSF.jpg',
#                   'width': 362},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoFifteenBySeven1305',
#                   'height': 609,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoFifteenBySeven1305',
#                   'subtype': 'videoFifteenBySeven1305',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoFifteenBySeven1305.jpg',
#                   'width': 1305},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoHpMedium',
#                   'height': 211,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoHpMedium',
#                   'subtype': 'videoHpMedium',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoHpMedium.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoLarge',
#                   'height': 507,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoLarge',
#                   'subtype': 'videoLarge',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoLarge.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine1050',
#                   'subtype': 'videoSixteenByNine1050',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine150',
#                   'height': 84,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine150',
#                   'subtype': 'videoSixteenByNine150',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine150.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine225',
#                   'height': 126,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine225',
#                   'subtype': 'videoSixteenByNine225',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine310',
#                   'height': 174,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine310',
#                   'subtype': 'videoSixteenByNine310',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine310.jpg',
#                   'width': 310},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine390',
#                   'height': 219,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine390',
#                   'subtype': 'videoSixteenByNine390',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine390.jpg',
#                   'width': 390},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine480',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine480',
#                   'subtype': 'videoSixteenByNine480',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine495',
#                   'height': 278,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine495',
#                   'subtype': 'videoSixteenByNine495',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine540',
#                   'height': 304,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine540',
#                   'subtype': 'videoSixteenByNine540',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine540.jpg',
#                   'width': 540},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine600',
#                   'height': 338,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine600',
#                   'subtype': 'videoSixteenByNine600',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine600.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine768',
#                   'height': 432,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine768',
#                   'subtype': 'videoSixteenByNine768',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine768.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine96',
#                   'height': 54,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine96',
#                   'subtype': 'videoSixteenByNine96',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNine96.jpg',
#                   'width': 96},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNineJumbo1600',
#                   'height': 793,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNineJumbo1600',
#                   'subtype': 'videoSixteenByNineJumbo1600',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSixteenByNineJumbo1600.jpg',
#                   'width': 1410},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSmall',
#                   'height': 281,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSmall',
#                   'subtype': 'videoSmall',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoSmall.jpg',
#                   'width': 500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoThumb',
#                   'subtype': 'videoThumb',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-videoThumb.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch268',
#                   'height': 303,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch268',
#                   'subtype': 'watch268',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-watch268.jpg',
#                   'width': 272},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch308',
#                   'height': 348,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch308',
#                   'subtype': 'watch308',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-watch308.jpg',
#                   'width': 312},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'windowsTile336H',
#                   'height': 336,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'windowsTile336H',
#                   'subtype': 'windowsTile336H',
#                   'type': 'image',
#                   'url': 'images/2018/02/18/books/review/18Pollan/18Pollan-windowsTile336H.jpg',
#                   'width': 694}],
#   'news_desk': 'BookReview',
#   'print_page': '11',
#   'pub_date': '2018-02-14T10:00:28+0000',
#   'score': 0.0,
#   'section_name': 'Books',
#   'snippet': 'In “Hippie Food,” Jonathan Kauffman tracks the emergence of the '
#              'organic, politicized diet so many Americans love today.',
#   'source': 'The New York Times',
#   'subsectoinName': 'Book Review',
#   'type_of_material': 'Review',
#   'uri': 'nyt://article/cc7409f9-12a0-5d35-998b-ee03ff6dde62',
#   'web_url': 'https://www.nytimes.com/2018/02/14/books/review/hippie-food-jonathan-kauffman.html',
#   'word_count': 1429},
#  {'_id': '5c3377f000a1bc2872e9ba72',
#   'blog': {},
#   'byline': {'organization': None,
#              'original': 'By FLORENCE FABRICANT',
#              'person': [{'firstname': 'Florence',
#                          'lastname': 'FABRICANT',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'article',
#   'headline': {'content_kicker': 'Front Burner',
#                'kicker': 'Front Burner',
#                'main': 'A New Syrup for Your Bar Cart',
#                'name': None,
#                'print_headline': 'To Sweeten: A New Syrup For Your Bar Cart',
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N',
#                 'name': 'subject',
#                 'rank': 1,
#                 'value': 'Cooking and Cookbooks'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 2,
#                 'value': 'Condiments'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Dates (Fruit)'},
#                {'major': 'N',
#                 'name': 'organizations',
#                 'rank': 4,
#                 'value': 'Soom Foods'}],
#   'lead_paragraph': 'Silan, a syrup made from dates, adds depth to whiskey '
#                     'cocktails and sweetness to marinades.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleLarge',
#                   'height': 400,
#                   'legacy': {'xlarge': 'images/2019/01/09/dining/09burner1/09burner1-articleLarge.jpg',
#                              'xlargeheight': 400,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-articleLarge.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbWide',
#                   'height': 126,
#                   'legacy': {'wide': 'images/2019/01/09/dining/09burner1/09burner1-thumbWide.jpg',
#                              'wideheight': 126,
#                              'widewidth': 190},
#                   'rank': 0,
#                   'subType': 'wide',
#                   'subtype': 'wide',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-thumbWide.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'thumbStandard',
#                   'height': 75,
#                   'legacy': {'thumbnail': 'images/2019/01/09/dining/09burner1/09burner1-thumbStandard.jpg',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subType': 'thumbnail',
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-thumbStandard.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'articleInline',
#                   'height': 127,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'articleInline',
#                   'subtype': 'articleInline',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-articleInline.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog225',
#                   'height': 150,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog225',
#                   'subtype': 'blog225',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-blog225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog427',
#                   'height': 285,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog427',
#                   'subtype': 'blog427',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-blog427.jpg',
#                   'width': 427},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog480',
#                   'height': 320,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog480',
#                   'subtype': 'blog480',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-blog480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blog533',
#                   'height': 355,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blog533',
#                   'subtype': 'blog533',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-blog533.jpg',
#                   'width': 533},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallInline',
#                   'height': 101,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallInline',
#                   'subtype': 'blogSmallInline',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-blogSmallInline.jpg',
#                   'width': 151},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'blogSmallThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'blogSmallThumb',
#                   'subtype': 'blogSmallThumb',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-blogSmallThumb.jpg',
#                   'width': 50},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'facebookJumbo',
#                   'height': 550,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'facebookJumbo',
#                   'subtype': 'facebookJumbo',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-facebookJumbo.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'filmstrip',
#                   'height': 190,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'filmstrip',
#                   'subtype': 'filmstrip',
#                   'type': 'image',
#                   'url': 'images/2019/01/09/dining/09burner1/09burner1-filmstrip.jpg',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
# ...
#                   'subType': 'videoHpMedium',
#                   'subtype': 'videoHpMedium',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoHpMedium.jpg',
#                   'width': 375},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoLarge',
#                   'height': 507,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoLarge',
#                   'subtype': 'videoLarge',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoLarge.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine1050',
#                   'height': 591,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine1050',
#                   'subtype': 'videoSixteenByNine1050',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine1050.jpg',
#                   'width': 1050},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine150',
#                   'height': 84,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine150',
#                   'subtype': 'videoSixteenByNine150',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine150.jpg',
#                   'width': 150},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine225',
#                   'height': 126,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine225',
#                   'subtype': 'videoSixteenByNine225',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine225.jpg',
#                   'width': 225},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine3000',
#                   'height': 1688,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine3000',
#                   'subtype': 'videoSixteenByNine3000',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine3000.jpg',
#                   'width': 3000},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine310',
#                   'height': 174,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine310',
#                   'subtype': 'videoSixteenByNine310',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine310.jpg',
#                   'width': 310},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine390',
#                   'height': 219,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine390',
#                   'subtype': 'videoSixteenByNine390',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine390.jpg',
#                   'width': 390},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine480',
#                   'height': 270,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine480',
#                   'subtype': 'videoSixteenByNine480',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine480.jpg',
#                   'width': 480},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine495',
#                   'height': 278,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine495',
#                   'subtype': 'videoSixteenByNine495',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine495.jpg',
#                   'width': 495},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine540',
#                   'height': 304,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine540',
#                   'subtype': 'videoSixteenByNine540',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine540.jpg',
#                   'width': 540},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine600',
#                   'height': 338,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine600',
#                   'subtype': 'videoSixteenByNine600',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine600.jpg',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine768',
#                   'height': 432,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine768',
#                   'subtype': 'videoSixteenByNine768',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine768.jpg',
#                   'width': 768},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNine96',
#                   'height': 54,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNine96',
#                   'subtype': 'videoSixteenByNine96',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNine96.jpg',
#                   'width': 96},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSixteenByNineJumbo1600',
#                   'height': 900,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSixteenByNineJumbo1600',
#                   'subtype': 'videoSixteenByNineJumbo1600',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSixteenByNineJumbo1600.jpg',
#                   'width': 1600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoSmall',
#                   'height': 281,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoSmall',
#                   'subtype': 'videoSmall',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoSmall.jpg',
#                   'width': 500},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'videoThumb',
#                   'height': 50,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'videoThumb',
#                   'subtype': 'videoThumb',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-videoThumb.jpg',
#                   'width': 75},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch268',
#                   'height': 303,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch268',
#                   'subtype': 'watch268',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-watch268.jpg',
#                   'width': 272},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'watch308',
#                   'height': 348,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'watch308',
#                   'subtype': 'watch308',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-watch308.jpg',
#                   'width': 312},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': 'windowsTile336H',
#                   'height': 336,
#                   'legacy': {},
#                   'rank': 0,
#                   'subType': 'windowsTile336H',
#                   'subtype': 'windowsTile336H',
#                   'type': 'image',
#                   'url': 'images/2019/01/23/crosswords/23wordplay-horse/merlin_81914342_9c126c9b-c333-4a8f-81f0-efbb89e312da-windowsTile336H.jpg',
#                   'width': 694}],
#   'news_desk': 'Games',
#   'pub_date': '2019-01-23T03:00:01+0000',
#   'score': 0.0,
#   'section_name': 'Crosswords & Games',
#   'snippet': 'Amanda Chung and Karl Ni take me down. And it’s only Wednesday.',
#   'source': 'The New York Times',
#   'type_of_material': 'News',
#   'uri': 'nyt://article/83cd1d78-fb48-54a2-9985-7aa03f3f5a2a',
#   'web_url': 'https://www.nytimes.com/2019/01/22/crosswords/daily-puzzle-2019-01-23.html',
#   'word_count': 623},
#  {'_id': '577b441838f0d83e1f65d766',
#   'blog': {},
#   'byline': {'organization': None,
#              'original': 'By KEVIN QUEALY and MARGOT SANGER-KATZ',
#              'person': [{'firstname': 'Kevin',
#                          'lastname': 'QUEALY',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 1,
#                          'role': 'reported',
#                          'title': None},
#                         {'firstname': 'Margot',
#                          'lastname': 'SANGER-KATZ',
#                          'middlename': None,
#                          'organization': '',
#                          'qualifier': None,
#                          'rank': 2,
#                          'role': 'reported',
#                          'title': None}]},
#   'document_type': 'multimedia',
#   'headline': {'content_kicker': None,
#                'kicker': '',
#                'main': 'Is Sushi ‘Healthy’? What About Granola? Where '
#                        'Americans and Nutritionists Disagree',
#                'name': None,
#                'print_headline': None,
#                'seo': None,
#                'sub': None},
#   'keywords': [{'major': 'N', 'name': 'subject', 'rank': 1, 'value': 'Sushi'},
#                {'major': 'N', 'name': 'subject', 'rank': 2, 'value': 'Food'},
#                {'major': 'N',
#                 'name': 'subject',
#                 'rank': 3,
#                 'value': 'Diet and Nutrition'}],
#   'lead_paragraph': 'We surveyed Americans and a panel of nutrition experts '
#                     'about which foods they thought were good or bad for you.',
#   'multimedia': [{'caption': None,
#                   'credit': None,
#                   'crop_name': None,
#                   'height': 619,
#                   'legacy': {'xlarge': 'images/2016/07/05/upshot/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326-articleLarge.png',
#                              'xlargeheight': 619,
#                              'xlargewidth': 600},
#                   'rank': 0,
#                   'subType': 'xlarge',
#                   'subtype': 'xlarge',
#                   'type': 'image',
#                   'url': 'images/2016/07/05/upshot/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326-articleLarge.png',
#                   'width': 600},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': None,
#                   'height': 126,
#                   'legacy': {'wide': 'images/2016/07/05/upshot/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326-thumbWide-v2.png',
#                              'wideheight': 126,
#                              'widewidth': 190},
#                   'rank': 0,
#                   'subType': 'wide',
#                   'subtype': 'wide',
#                   'type': 'image',
#                   'url': 'images/2016/07/05/upshot/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326-thumbWide-v2.png',
#                   'width': 190},
#                  {'caption': None,
#                   'credit': None,
#                   'crop_name': None,
#                   'height': 75,
#                   'legacy': {'thumbnail': 'images/2016/07/05/upshot/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326-thumbStandard-v2.png',
#                              'thumbnailheight': 75,
#                              'thumbnailwidth': 75},
#                   'rank': 0,
#                   'subType': 'thumbnail',
#                   'subtype': 'thumbnail',
#                   'type': 'image',
#                   'url': 'images/2016/07/05/upshot/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326/what-foods-are-healthy-americans-dont-agree-and-neither-do-nutrition-experts-1467313136326-thumbStandard-v2.png',
#                   'width': 75}],
#   'news_desk': 'The Upshot',
#   'pub_date': '2016-07-05T05:22:35+0000',
#   'score': 0.0,
#   'section_name': 'The Upshot',
#   'snippet': 'We surveyed Americans and a panel of nutrition experts about '
#              'which foods they thought were good or bad for you.',
#   'source': 'The New York Times',
#   'type_of_material': 'Interactive Feature',
#   'uri': 'nyt://interactive/5df7c518-4f88-5b54-9a33-8e5f980bb1a8',
#   'web_url': 'https://www.nytimes.com/interactive/2016/07/05/upshot/is-sushi-healthy-what-about-granola-where-americans-and-nutritionists-disagree.html',
#   'word_count': 0}]

# %%
# Print the web_url of each stored article
print("Your Reading List")
for article in articles_list:
    print(article["web_url"])
# Out:
# Your Reading List
# https://cooking.nytimes.com/recipes/1019514-granola-bites
# https://www.nytimes.com/2018/02/14/books/review/hippie-food-jonathan-kauffman.html
# https://www.nytimes.com/2019/01/07/dining/silan-syrup.html
# https://www.nytimes.com/2016/08/30/well/eat/why-your-granola-is-really-a-dessert.html
# https://www.nytimes.com/2016/05/11/dining/granola-recipe-clusters-video.html
# https://www.nytimes.com/2019/02/01/well/eat/are-natural-flavors-really-natural.html
# https://www.nytimes.com/video/dining/100000004388480/granola-clusters.html
# https://www.nytimes.com/2019/01/04/dining/what-to-cook-this-weekend.html
# https://www.nytimes.com/2019/01/22/crosswords/daily-puzzle-2019-01-23.html
# https://www.nytimes.com/interactive/2016/07/05/upshot/is-sushi-healthy-what-about-granola-where-americans-and-nutritionists-disagree.html
